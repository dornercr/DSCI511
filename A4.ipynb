# %% [markdown]
# <a href="https://colab.research.google.com/github/dornercr/DSCI511/blob/main/A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 4
# ## Assignment submission header
# ### Submission preparation instructions
# Please provide the names and Drexel email addresses of all group members. If applicable, provide notes on any tutoring support received toward the completion of this submission.
#
# ### Assignment submission group
# - Group member 1: Name (email)
# - Group member 2: Name (email)
# - Group member 3: Name (email)
# - Group member 4: Name (email)
#
# ### Additional submission comments
# - Tutoring support received: NA
# - Other (other): NA

# %% [markdown]
# Part 1 (50 points)
#
# For this assignment, you will set up a toolkit for plain text enhancement and concept-based annotation.
# More specifically, you will use a local annotation service provided with the assignment.
# This service simulates the output structure of common entity‐linking APIs by supplying:
#
# - tokenized text
#
# - whitespace information
#
# - synthetic concept annotations
#
# - character spans associated with each concept
#
# These annotations are stored in pre-generated JSON files located in the ./annotations/ directory.
# Each annotation file corresponds to one scientific article in the dataset and is modeled after the type of output you would receive from an online text annotation API.
#
# Before starting Part 1, ensure that you have downloaded:
#
# - the CSV dataset toy_science_articles.csv
#
# - all JSON annotation files located in ./annotations/
#
# You will build functions to load, reconstruct, and enrich document text using these local annotation files.

# %% [markdown]
# __1a.__ (8 points) Loading annotation JSON
#
# Write a function load_annotations(article_id) that:
#
# - Loads the JSON file from ./annotations/article_<id>.json
#
# - Returns the parsed Python object
#
# - Prints the keys of the first concept object in ["concepts"]
#
# Use article id = 1 for testing.

# %% [markdown]
# __1b.__ (8 points) Text caching system
#
# Write a function get_or_cache_text(article_id) that:
#
# 1. Looks for a cached file:
# ./cache/article_<id>_text.txt
#
# 2. If it exists, load and return the cached text.
#
# 3. Otherwise:
#
# - reconstruct the text from the JSON
#
# - save it to the cache
#
# - return the text
#
# Test with article id = 3.
# Print the first 120 characters.

# %% [markdown]
# __1c.__ (7 points) Reconstructing text from tokens + spaces
#
# Write a function reconstruct_text(annotations_json) that:
#
# - Interleaves each spaces[i] + tokens[i]
#
# - Appends spaces[-1] at the end
#
# - Returns the full text string
#
# Test using the JSON loaded in 1a.

# %% [markdown]
# __1d.__ (7 points) Extracting spans
#
# Write extract_spans(annotations_json) to return all spans as:
#
# (start, end, label)
#
# Flatten all concept entries and all their spans.
#
# Test using article id = 3.
# Print:
#
# - number of spans
#
# - first span tuple

# %% [markdown]
# __1e.__ (5 points) Embedding a single span
#
# Write embed_span(text, span_tuple) that:
#
# - Wraps the characters [start:end+1] in:
#
# "<span data-label="LABEL"> ... </span>"
#
# Return the modified text.
#
# Test using one span extracted in 1d.

# %% [markdown]
# __1f.__ (4 points) Keeping only the longest span per concept
#
# Write filter_longest_spans(annotations_json) that:
#
# - For each unique label, keep the span with maximum (end - start)
#
# - Return a list of span tuples sorted by label
#
# Print first 5 results.

# %% [markdown]
# __1g.__ (6 points) Embedding all spans without overlap
#
# Write embed_all_spans(annotations_json) that:
#
# - Reconstructs the document
#
# - Gets longest spans from 1f
#
# - Sorts spans descending by end
#
# - Embeds only if spans do not overlap
#
# - Returns the final HTML-enriched article
#
# Print the first 300 characters.

# %% [markdown]
# __1h.__ (5 points) Creating the enrichment module
#
# Create a module:
#
# concept_enricher.py
#
# containing all functions from 1a–1g:
#
# - Use inspect.getsource to extract source
#
# - Join functions with two newlines
#
# - Write to concept_enricher.py
#
# - Use relative paths only
#
# Then test:
#
# import concept_enricher as ce
#
# ann = ce.load_annotations(3)
# html = ce.embed_all_spans(ann)
# print(html[:300])

# %% [markdown]
# Part 2 (50 points)
#
# In this part of the assignment, you will extend the functionality of your text-processing toolkit to create a backend enrichment system for scientific articles.
#
# More specifically, you will use the functions you created in Part 1 to:
#
# - embed concept annotations directly into article text
#
# - generate enriched HTML versions of all articles
#
# - build searchable metadata structures
#
# - assemble a complete reader-ready package containing all processed content
#
# This stage of the assignment mirrors how real-world digital reading systems (such as e-readers, educational platforms, or research assistants) prepare and enrich text with semantic information.
# Your task is to integrate all earlier components into a unified pipeline that produces a polished, structured output package.
#
# Before starting Part 2, verify that:
#
# - Your functions from Part 1 operate correctly
#
# - Your concept_enricher.py module is properly exported
#
# - Your annotation JSON files and CSV dataset are accessible from the working directory
#
# You will now create a fully automated text enrichment system that processes all documents end-to-end.

# %% [markdown]
# __2a.__ (6 points) — Previewing Raw Article Text
#
# Write a function:
#
# preview_article(article_id)
#
# that:
#
# - Loads the annotation JSON (load_annotations)
#
# - Reconstructs the full article text (reconstruct_text)
#
# - Prints the first 200 characters
#
# - Prints the number of concepts found in the file
#
# Test with article id = 5.

# %% [markdown]
# __2b.__ (7 points) — Embedding All Concept Labels
#
# Write a function:
#
# embed_article(article_id)
#
# that:
#
# 1. Loads the annotation JSON
#
# 2. Calls embed_all_spans
#
# 3. Returns the fully enriched HTML string
#
# Test using article id = 2 and print the first 300 characters.

# %% [markdown]
# __2c.__ (7 points) — Saving Enriched Files to HTML
#
# Write a function:
#
# save_enriched_article(article_id)
#
# that:
#
# - Calls embed_article(article_id)
#
# - Saves the result to:
#
# ./html/article_<id>.html
#
# - Ensures the output directory exists
#
# - Returns the output path as a string
#
# Demonstrate using article id = 1 and show the resolved file path.

# %% [markdown]
# __2d.__ (6 points) Batch Processing All Articles
#
# Write a function:
#
# batch_enrich_all()
#
# that:
#
# - Loads the CSV file
#
# - Iterates through all article IDs
#
# - Calls save_enriched_article for each
#
# - Prints a status line such as:
#
# Enriched article 7 → ./html/article_7.html
#
# Test it on the full dataset (10 files).

# %% [markdown]
# __2e.__ (8 points) — Building a Searchable Metadata Index
#
# Each annotation JSON contains:
#
# - concept label
#
# - confidence
#
# - spans
#
# Write a function:
#
# build_metadata_index()
#
# that creates a list of index entries:
#
# {
#     "article_id": ...,
#     "label": ...,
#     "confidence": ...,
#     "span_count": ...,
# }
#
# Save the final index as:
#
# ./html/concept_index.json
#
# Print the number of unique concept labels across the dataset.

# %% [markdown]
# __2f.__ (8 points) — Generating a Summary Table of Concept Frequencies
#
# Write a function:
#
# build_concept_report()
#
# that:
#
# - Loads concept_index.json
#
# - Aggregates total frequency per concept label
#
# - Sorts by descending frequency
#
# - Writes the table to:
#
# ./html/concept_report.csv
#
# Print the top 5 most frequent concepts.

# %% [markdown]
# __2g.__ (8 points) — Integrating Everything into an E-Reader Package
#
# Write a master function:
#
# generate_reader_package()
#
# that:
#
# 1. Runs batch_enrich_all()
#
# 2. Runs build_metadata_index()
#
# 3. Runs build_concept_report()
#
# 4. Creates a folder:
#
# ./reader_package/
#
# 5. Copies:
#
# - all HTML article outputs
#
# - the concept index
#
# - the concept report
#
# 6. Prints confirmation:
#
# Reader package generated with 10 articles, metadata index, and report.
#
# Run generate_reader_package() and show the printed confirmation.
