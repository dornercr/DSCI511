# %% [markdown]
# <a href="https://colab.research.google.com/github/dornercr/DSCI511/blob/main/DSCI511_Week3_Data_Acquisition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DSCI 511: Data acquisition and pre-processing <br>Chapter 3: Acquiring Data from the Internet
#
# ## 3.1 APIs
# The entire infrastructure of the internet uses three basic ideas as building blocks: clients, servers, and requests. When you visit a website, your web browser is the _client_. In order to display the web page to you, your browser makes a _request_ to a remote _server_. The server then processes the request and sends back the page, which is essentially an HTML document. Your browser can interpret this document, which contains all kinds of information (including styling and presentation-related information and hyperlinks), and display it on your screen.
#
# ### 3.1.1 What is an API?
# An _Application Processing Interface_ (API) allows you to make a request to a remote server to obtain data instead of a web page. So instead of an HTML document, usually an API request will return some data in a format like, JSON, CSV, or XML. To review how to load data from these formats review Chapter 1.

# %% [markdown]
# ### 3.1.2 Accessing APIs
# When you access a web page, your browser makes a request to the remote server. The browser uses a URL address to send the request. Similarly, URLs are also used to send requests to APIs. Usually, constructing the URL needed to send the request is an important early step in working with APIs.
# #### 3.1.2.1 Making Requests and handling JSON responses
# When writing Python code to get data from APIs, we'll use the `requests` module to make these requests. The `requests.get()` method can be supplied with a URL, and returns a "response" object, which has a very convenient `.json()` method to process the response when it is a JSON file and return a dictionary (so we don't necessarily have to use the `json` module to de-serialize a request's text result. For example, we'll use the GitHub API to grab some data about a user.

# %%
import requests

# format: "https://api.github.com/user/USERNAME"
response = requests.get("https://api.github.com/users/leiwangdrexel")

# json.loads(response.text)

response.json()
# Out:
# {'login': 'leiwangDrexel',
#  'id': 75227593,
#  'node_id': 'MDQ6VXNlcjc1MjI3NTkz',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/75227593?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/leiwangDrexel',
#  'html_url': 'https://github.com/leiwangDrexel',
#  'followers_url': 'https://api.github.com/users/leiwangDrexel/followers',
#  'following_url': 'https://api.github.com/users/leiwangDrexel/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/leiwangDrexel/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/leiwangDrexel/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/leiwangDrexel/subscriptions',
#  'organizations_url': 'https://api.github.com/users/leiwangDrexel/orgs',
#  'repos_url': 'https://api.github.com/users/leiwangDrexel/repos',
#  'events_url': 'https://api.github.com/users/leiwangDrexel/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/leiwangDrexel/received_events',
#  'type': 'User',
#  'user_view_type': 'public',
#  'site_admin': False,
#  'name': None,
#  'company': None,
#  'blog': '',
#  'location': None,
#  'email': None,
#  'hireable': None,
#  'bio': None,
#  'twitter_username': None,
#  'public_repos': 1,
#  'public_gists': 0,
#  'followers': 0,
#  'following': 0,
#  'created_at': '2020-11-29T23:49:44Z',
#  'updated_at': '2023-11-03T17:32:55Z'}

# %% [markdown]
# GitHub's API doesn't require an "access token" to return this information about a user. There are thousands of public APIs available on the web that can help you get useful data, and many of them can be used as simply as this GitHub example.
# #### 3.1.2.2 A more local example of an API
# The Southeastern Pennsylvania Transportation Authority (SEPTA) [makes a few APIs available](http://www3.septa.org/hackathon/). Some of these APIs can be used to access realtime data about SEPTA transit (trains, buses, trolleys). For example, we can request data about the next trains to arrive at a given station.

# %%
# format: "http://www3.septa.org/hackathon/Arrivals/*STATION_NAME*/*NUMBER_OF_TRAINS*"
arrivals_response = requests.get("http://www3.septa.org/hackathon/Arrivals/30th Street Station/5")
arrivals_response.text
# Out:
# '\n{"Gray 30th Street Departures: October 7, 2025, 10:40 am":[{"Northbound":[{"direction":"N","path":"R7N","train_id":"708","origin":"North Philadelphia","destination":"Chestnut H East","line":"Trenton","status":"7 min","service_type":"LOCAL","next_station":"North Philadelphia","sched_time":"2025-10-07 10:46:00.000","depart_time":"2025-10-07 10:47:00.000","track":"2","track_change":null,"platform":"","platform_change":null},{"direction":"N","path":"R3\\/2N","train_id":"3214","origin":"Wallingford","destination":"Norristown","line":"Media\\/Wawa","status":"21 min","service_type":"LOCAL","next_station":"Wallingford","sched_time":"2025-10-07 10:51:01.000","depart_time":"2025-10-07 10:52:00.000","track":"5","track_change":null,"platform":"","platform_change":null},{"direction":"N","path":"R2\\/4N","train_id":"9212","origin":"Curtis Park","destination":"Temple U","line":"Wilmington\\/Newark","status":"On Time","service_type":"LOCAL","next_station":"Curtis Park","sched_time":"2025-10-07 10:55:01.000","depart_time":"2025-10-07 10:56:00.000","track":"5","track_change":null,"platform":"","platform_change":null},{"direction":"N","path":"R4N","train_id":"424","origin":"Airport Terminal A","destination":"Warminster","line":"Airport","status":"On Time","service_type":"LOCAL","next_station":"Airport","sched_time":"2025-10-07 10:59:00.000","depart_time":"2025-10-07 11:00:00.000","track":"5","track_change":null,"platform":"","platform_change":null},{"direction":"N","path":"R8N","train_id":"9820","origin":"Chelten Avenue","destination":"Temple U","line":"Chestnut Hill West","status":"1 min","service_type":"LOCAL","next_station":"Chelten Avenue","sched_time":"2025-10-07 10:59:00.000","depart_time":"2025-10-07 11:00:00.000","track":"2","track_change":null,"platform":"","platform_change":null}]},{"Southbound":[{"direction":"S","path":"R5S","train_id":"9513","origin":"Temple U","destination":"Malvern","line":"Paoli\\/Thorndale","status":"On Time","service_type":"LOCAL","next_station":"Jefferson","sched_time":"2025-10-07 10:55:00.000","depart_time":"2025-10-07 10:56:00.000","track":"4","track_change":null,"platform":"","platform_change":null},{"direction":"S","path":"R4S","train_id":"9427","origin":"Temple U","destination":"Airport","line":"Airport","status":"5 min","service_type":"LOCAL","next_station":null,"sched_time":"2025-10-07 10:58:00.000","depart_time":"2025-10-07 10:59:00.000","track":"6","track_change":null,"platform":"","platform_change":null},{"direction":"S","path":"R8S","train_id":"821","origin":"Fox Chase","destination":"Chestnut H West","line":"Chestnut Hill West","status":"On Time","service_type":"LOCAL","next_station":"Temple U","sched_time":"2025-10-07 11:01:00.000","depart_time":"2025-10-07 11:02:00.000","track":"3","track_change":null,"platform":"","platform_change":null},{"direction":"S","path":"R2\\/3S","train_id":"2311","origin":"Elm St","destination":"Wawa","line":"Manayunk\\/Norristown","status":"On Time","service_type":"LOCAL","next_station":"Allegheny","sched_time":"2025-10-07 11:02:00.000","depart_time":"2025-10-07 11:03:00.000","track":"6","track_change":null,"platform":"","platform_change":null},{"direction":"S","path":"R4S","train_id":"429","origin":"Warminster","destination":"Airport","line":"Warminster","status":"15 min","service_type":"LOCAL","next_station":null,"sched_time":"2025-10-07 11:28:00.000","depart_time":"2025-10-07 11:29:00.000","track":"6","track_change":null,"platform":"","platform_change":null}]}]}'

# %%
arrivals_dict = arrivals_response.json()
arrivals_dict
# Out:
# {'Gray 30th Street Departures: October 7, 2025, 10:40 am': [{'Northbound': [{'direction': 'N',
#      'path': 'R7N',
#      'train_id': '708',
#      'origin': 'North Philadelphia',
#      'destination': 'Chestnut H East',
#      'line': 'Trenton',
#      'status': '7 min',
#      'service_type': 'LOCAL',
#      'next_station': 'North Philadelphia',
#      'sched_time': '2025-10-07 10:46:00.000',
#      'depart_time': '2025-10-07 10:47:00.000',
#      'track': '2',
#      'track_change': None,
#      'platform': '',
#      'platform_change': None},
#     {'direction': 'N',
#      'path': 'R3/2N',
#      'train_id': '3214',
#      'origin': 'Wallingford',
#      'destination': 'Norristown',
#      'line': 'Media/Wawa',
#      'status': '21 min',
#      'service_type': 'LOCAL',
#      'next_station': 'Wallingford',
#      'sched_time': '2025-10-07 10:51:01.000',
#      'depart_time': '2025-10-07 10:52:00.000',
#      'track': '5',
#      'track_change': None,
#      'platform': '',
#      'platform_change': None},
#     {'direction': 'N',
#      'path': 'R2/4N',
#      'train_id': '9212',
#      'origin': 'Curtis Park',
#      'destination': 'Temple U',
#      'line': 'Wilmington/Newark',
#      'status': 'On Time',
#      'service_type': 'LOCAL',
#      'next_station': 'Curtis Park',
#      'sched_time': '2025-10-07 10:55:01.000',
#      'depart_time': '2025-10-07 10:56:00.000',
#      'track': '5',
#      'track_change': None,
#      'platform': '',
#      'platform_change': None},
#     {'direction': 'N',
#      'path': 'R4N',
#      'train_id': '424',
#      'origin': 'Airport Terminal A',
#      'destination': 'Warminster',
#      'line': 'Airport',
#      'status': 'On Time',
#      'service_type': 'LOCAL',
#      'next_station': 'Airport',
#      'sched_time': '2025-10-07 10:59:00.000',
#      'depart_time': '2025-10-07 11:00:00.000',
#      'track': '5',
#      'track_change': None,
#      'platform': '',
#      'platform_change': None},
#     {'direction': 'N',
#      'path': 'R8N',
#      'train_id': '9820',
#      'origin': 'Chelten Avenue',
#      'destination': 'Temple U',
#      'line': 'Chestnut Hill West',
#      'status': '1 min',
#      'service_type': 'LOCAL',
#      'next_station': 'Chelten Avenue',
#      'sched_time': '2025-10-07 10:59:00.000',
#      'depart_time': '2025-10-07 11:00:00.000',
#      'track': '2',
#      'track_change': None,
#      'platform': '',
#      'platform_change': None}]},
#   {'Southbound': [{'direction': 'S',
#      'path': 'R5S',
#      'train_id': '9513',
#      'origin': 'Temple U',
#      'destination': 'Malvern',
#      'line': 'Paoli/Thorndale',
#      'status': 'On Time',
#      'service_type': 'LOCAL',
#      'next_station': 'Jefferson',
#      'sched_time': '2025-10-07 10:55:00.000',
#      'depart_time': '2025-10-07 10:56:00.000',
#      'track': '4',
#      'track_change': None,
#      'platform': '',
#      'platform_change': None},
#     {'direction': 'S',
#      'path': 'R4S',
#      'train_id': '9427',
#      'origin': 'Temple U',
#      'destination': 'Airport',
#      'line': 'Airport',
#      'status': '5 min',
#      'service_type': 'LOCAL',
#      'next_station': None,
#      'sched_time': '2025-10-07 10:58:00.000',
#      'depart_time': '2025-10-07 10:59:00.000',
#      'track': '6',
#      'track_change': None,
#      'platform': '',
#      'platform_change': None},
#     {'direction': 'S',
#      'path': 'R8S',
#      'train_id': '821',
#      'origin': 'Fox Chase',
#      'destination': 'Chestnut H West',
#      'line': 'Chestnut Hill West',
#      'status': 'On Time',
#      'service_type': 'LOCAL',
#      'next_station': 'Temple U',
#      'sched_time': '2025-10-07 11:01:00.000',
#      'depart_time': '2025-10-07 11:02:00.000',
#      'track': '3',
#      'track_change': None,
#      'platform': '',
#      'platform_change': None},
#     {'direction': 'S',
#      'path': 'R2/3S',
#      'train_id': '2311',
#      'origin': 'Elm St',
#      'destination': 'Wawa',
#      'line': 'Manayunk/Norristown',
#      'status': 'On Time',
#      'service_type': 'LOCAL',
#      'next_station': 'Allegheny',
#      'sched_time': '2025-10-07 11:02:00.000',
#      'depart_time': '2025-10-07 11:03:00.000',
#      'track': '6',
#      'track_change': None,
#      'platform': '',
#      'platform_change': None},
#     {'direction': 'S',
#      'path': 'R4S',
#      'train_id': '429',
#      'origin': 'Warminster',
#      'destination': 'Airport',
#      'line': 'Warminster',
#      'status': '15 min',
#      'service_type': 'LOCAL',
#      'next_station': None,
#      'sched_time': '2025-10-07 11:28:00.000',
#      'depart_time': '2025-10-07 11:29:00.000',
#      'track': '6',
#      'track_change': None,
#      'platform': '',
#      'platform_change': None}]}]}

# %% [markdown]
# #### 3.1.2.3 Exercise: processing a JSON response
# Make a request to the SEPTA Arrivals API to get data on the next 10 trains to arrive at Suburban Station. Store this JSON-format data into a dictionary. Inspect the dictionary structure. Then, write code to create a list containing 10 dictionaries, one for each train. These new dictionaries should look like this:

# %%
from pprint import pprint
# example of train dictionary format
train_dict = {
    'direction': 'S',
     'line': 'Media/Elwyn',
     'sched_time': '2018-08-22 17:31:01.000',
     'status': 'On Time',
     'track': '6'
}

pprint(train_dict)
# Out:
# {'direction': 'S',
#  'line': 'Media/Elwyn',
#  'sched_time': '2018-08-22 17:31:01.000',
#  'status': 'On Time',
#  'track': '6'}

# %% [markdown]
# #### 3.1.2.4 Open geo-location data
# Geolocation data can also be found in JSON format. The [OpenStreetMap (OSM) API](https://wiki.openstreetmap.org/wiki/Main_Page) can be used to request geographic data. Usually, map data is stored in the form of polygons, shapes with vertices consisting of latitude-longitude points. For example, we can obtain the polygon for Philadelphia from OSM like this:

# %%
import requests
from pprint import pprint

url = "https://nominatim.openstreetmap.org/search.php"
params = {
    "q": "Philadelphia, Pennsylvania",
    "polygon_geojson": 1,
    "format": "json"
}
headers = {
    "User-Agent": "MyApp/1.0 (contact@myapp.com)"  # required by Nominatim
}

response = requests.get(url, params=params, headers=headers)

# Verify success
if response.status_code == 200 and response.text.strip():
    try:
        geo_locations = response.json()
        pprint(geo_locations)  # pretty print full JSON
    except ValueError as e:
        print("JSON Decode Error:", e)
        print(response.text[:500])  # show partial response
else:
    print(f"HTTP {response.status_code}:")
    print(response.text[:500])
# Out:
# [{'addresstype': 'city',
#   'boundingbox': ['39.8670050', '40.1379593', '-75.2802660', '-74.9558314'],
#   'class': 'boundary',
#   'display_name': 'Philadelphia, Philadelphia County, Pennsylvania, United '
#                   'States',
#   'geojson': {'coordinates': [[[-75.280266, 39.974964],
#                                [-75.28023, 39.974888],
#                                [-75.280192, 39.974835],
#                                [-75.28013, 39.974735],
#                                [-75.280085, 39.974624],
#                                [-75.280044, 39.97454],
#                                [-75.280027, 39.974502],
#                                [-75.279955, 39.974424],
#                                [-75.279805, 39.97432],
#                                [-75.2796, 39.974185],
#                                [-75.279465, 39.974122],
#                                [-75.279359, 39.974072],
#                                [-75.279242, 39.974031],
#                                [-75.27917, 39.973986],
#                                [-75.279123, 39.973913],
#                                [-75.279109, 39.973812],
#                                [-75.279081, 39.973691],
#                                [-75.279046, 39.973618],
#                                [-75.278998, 39.973526],
#                                [-75.278971, 39.973446],
#                                [-75.278952, 39.973359],
#                                [-75.278916, 39.973315],
#                                [-75.278859, 39.973247],
#                                [-75.27883, 39.973162],
#                                [-75.27881, 39.973051],
#                                [-75.278795, 39.97295],
#                                [-75.278784, 39.972841],
#                                [-75.27878, 39.972745],
#                                [-75.278777, 39.972692],
#                                [-75.278759, 39.972634],
#                                [-75.278724, 39.97253],
#                                [-75.278697, 39.972414],
#                                [-75.278657, 39.972332],
#                                [-75.278609, 39.972263],
#                                [-75.278537, 39.972185],
#                                [-75.278449, 39.972106],
#                                [-75.278352, 39.972013],
#                                [-75.278297, 39.971928],
#                                [-75.278018, 39.971751],
#                                [-75.277967, 39.971714],
#                                [-75.277886, 39.971693],
#                                [-75.277765, 39.971678],
#                                [-75.277676, 39.971659],
#                                [-75.277641, 39.971643],
#                                [-75.277591, 39.971615],
#                                [-75.277553, 39.971583],
#                                [-75.277529, 39.971555],
#                                [-75.277513, 39.971518],
#                                [-75.277505, 39.971487],
#                                [-75.277503, 39.971452],
#                                [-75.277509, 39.971424],
#                                [-75.277523, 39.971401],
#                                [-75.277551, 39.971386],
#                                [-75.277596, 39.971377],
#                                [-75.277646, 39.971362],
#                                [-75.277688, 39.971345],
#                                [-75.277713, 39.971321],
#                                [-75.277704, 39.971284],
#                                [-75.277687, 39.971247],
#                                [-75.277656, 39.971209],
#                                [-75.277611, 39.971175],
#                                [-75.277576, 39.97115],
#                                [-75.27754, 39.971127],
#                                [-75.277491, 39.97111],
#                                [-75.277421, 39.971097],
#                                [-75.277338, 39.971083],
#                                [-75.277266, 39.971082],
#                                [-75.277198, 39.971082],
#                                [-75.277136, 39.971089],
#                                [-75.277073, 39.971105],
#                                [-75.276896, 39.971175],
#                                [-75.276825, 39.971215],
#                                [-75.27676, 39.971244],
#                                [-75.276689, 39.971253],
#                                [-75.276583, 39.971262],
#                                [-75.276524, 39.971224],
#                                [-75.276485, 39.971178],
#                                [-75.276471, 39.971135],
#                                [-75.276528, 39.971095],
#                                [-75.276587, 39.971056],
#                                [-75.276636, 39.971016],
#                                [-75.276662, 39.970983],
#                                [-75.276674, 39.970945],
#                                [-75.276667, 39.970907],
#                                [-75.276656, 39.970862],
#                                [-75.27664, 39.970828],
#                                [-75.276611, 39.970776],
#                                [-75.276553, 39.970672],
#                                [-75.276508, 39.97059],
#                                [-75.276467, 39.97052],
#                                [-75.276438, 39.970468],
#                                [-75.276411, 39.970416],
#                                [-75.27637, 39.970388],
#                                [-75.276302, 39.970351],
#                                [-75.276277, 39.970342],
#                                [-75.276245, 39.97033],
#                                [-75.276186, 39.970324],
#                                [-75.276005, 39.970312],
#                                [-75.275819, 39.97031],
#                                [-75.275705, 39.970293],
#                                [-75.275652, 39.970259],
#                                [-75.275606, 39.970211],
#                                [-75.275567, 39.970125],
#                                [-75.275494, 39.969929],
#                                [-75.275456, 39.969778],
#                                [-75.275394, 39.969575],
#                                [-75.275362, 39.969503],
#                                [-75.27532, 39.969411],
#                                [-75.275266, 39.969364],
#                                [-75.275197, 39.969325],
#                                [-75.275084, 39.969297],
#                                [-75.275027, 39.969289],
#                                [-75.274889, 39.969287],
#                                [-75.274808, 39.969293],
#                                [-75.274488, 39.96931],
#                                [-75.274326, 39.969316],
#                                [-75.27415, 39.969317],
#                                [-75.274012, 39.969315],
#                                [-75.273912, 39.96931],
#                                [-75.27381, 39.969297],
#                                [-75.273681, 39.969287],
#                                [-75.273569, 39.969278],
#                                [-75.273492, 39.969276],
#                                [-75.273415, 39.969281],
#                                [-75.27328, 39.969294],
#                                [-75.273185, 39.969305],
#                                [-75.273054, 39.969305],
#                                [-75.272957, 39.969293],
#                                [-75.272815, 39.969244],
#                                [-75.272726, 39.969217],
#                                [-75.272625, 39.969178],
#                                [-75.272505, 39.969131],
#                                [-75.272344, 39.969094],
#                                [-75.272196, 39.969047],
#                                [-75.272086, 39.969011],
#                                [-75.272024, 39.968985],
#                                [-75.271985, 39.968944],
#                                [-75.271922, 39.968859],
#                                [-75.271863, 39.968805],
#                                [-75.271802, 39.968756],
#                                [-75.271698, 39.968729],
#                                [-75.27159, 39.968715],
#                                [-75.271491, 39.968709],
#                                [-75.271407, 39.968704],
#                                [-75.271327, 39.968691],
#                                [-75.271241, 39.968663],
#                                [-75.271168, 39.968633],
#                                [-75.271109, 39.968619],
#                                [-75.271043, 39.968609],
#                                [-75.270986, 39.968603],
#                                [-75.270913, 39.968619],
#                                [-75.270838, 39.968644],
#                                [-75.270773, 39.968663],
#                                [-75.270718, 39.968671],
#                                [-75.270651, 39.968675],
#                                [-75.270598, 39.96866],
#                                [-75.27057, 39.968638],
#                                [-75.270522, 39.968602],
#                                [-75.270501, 39.968585],
#                                [-75.270447, 39.968528],
#                                [-75.270422, 39.968479],
#                                [-75.270413, 39.968428],
#                                [-75.270402, 39.968357],
#                                [-75.270388, 39.968322],
#                                [-75.270297, 39.968184],
#                                [-75.257629, 39.963664],
#                                [-75.257543, 39.963705],
#                                [-75.257487, 39.963744],
#                                [-75.257418, 39.963766],
#                                [-75.2573049, 39.9637752],
#                                [-75.2572326, 39.9637761],
#                                [-75.2571266, 39.9637643],
#                                [-75.256981, 39.963688],
#                                [-75.2569, 39.963672],
#                                [-75.256816, 39.963677],
#                                [-75.256746, 39.963688],
#                                [-75.256686, 39.963719],
#                                [-75.256586, 39.963802],
#                                [-75.256383, 39.963974],
#                                [-75.256281, 39.964079],
#                                [-75.256193, 39.964155],
#                                [-75.256083, 39.964242],
#                                [-75.255966, 39.964312],
#                                [-75.255892, 39.964372],
#                                [-75.255852, 39.964437],
#                                [-75.255812, 39.964471],
#                                [-75.255686, 39.964546],
#                                [-75.255543, 39.964595],
#                                [-75.255409, 39.96463],
#                                [-75.255267, 39.964655],
#                                [-75.255112, 39.964691],
#                                [-75.254937, 39.964763],
#                                [-75.254738, 39.96485],
#                                [-75.254632, 39.964925],
#                                [-75.254543, 39.964992],
#                                [-75.254456, 39.965046],
#                                [-75.254381, 39.965127],
#                                [-75.254337, 39.965211],
#                                [-75.254302, 39.965273],
#                                [-75.254223, 39.965337],
#                                [-75.25414, 39.965404],
#                                [-75.254046, 39.965402],
#                                [-75.253936, 39.96539],
#                                [-75.253712, 39.965329],
#                                [-75.253582, 39.9653],
#                                [-75.253407, 39.965261],
#                                [-75.253314, 39.965226],
#                                [-75.2532779, 39.9652146],
#                                [-75.2532156, 39.9651949],
#                                [-75.253077, 39.965214],
#                                [-75.252972, 39.965235],
#                                [-75.252843, 39.965244],
#                                [-75.252636, 39.965251],
#                                [-75.252334, 39.96528],
#                                [-75.252094, 39.965305],
#                                [-75.251923, 39.965318],
#                                [-75.251811, 39.96533],
#                                [-75.251707, 39.965346],
#                                [-75.251603, 39.965356],
#                                [-75.251496, 39.965337],
#                                [-75.251427, 39.965302],
#                                [-75.251368, 39.965249],
#                                [-75.251353, 39.965219],
#                                [-75.251341, 39.965192],
#                                [-75.251336, 39.965138],
#                                [-75.251342, 39.965072],
#                                [-75.251283, 39.965003],
#                                [-75.251201, 39.964912],
#                                [-75.2511683, 39.9648942],
#                                [-75.251102, 39.964858],
#                                [-75.2510368, 39.9648333],
#                                [-75.250913, 39.964837],
#                                [-75.250757, 39.964879],
#                                [-75.250606, 39.964948],
#                                [-75.2504297, 39.9650246],
#                                [-75.250313, 39.965069],
#                                [-75.250221, 39.965076],
#                                [-75.250133, 39.965067],
#                                [-75.2500501, 39.9650395],
#                                [-75.24999, 39.965001],
#                                [-75.249912, 39.964947],
#                                [-75.249848, 39.964908],
#                                [-75.2497449, 39.9648582],
#                                [-75.249465, 39.964721],
#                                [-75.248967, 39.964494],
#                                [-75.248615, 39.964352],
#                                [-75.248056, 39.964074],
#                                [-75.247903, 39.963979],
#                                [-75.247778, 39.963876],
#                                [-75.247685, 39.963777],
#                                [-75.247564, 39.963638],
#                                [-75.247479, 39.963528],
#                                [-75.247434, 39.963417],
#                                [-75.247405, 39.963327],
#                                [-75.247399, 39.963249],
#                                [-75.227952, 40.025934],
#                                [-75.226652, 40.025267],
#                                [-75.226513, 40.025197],
#                                [-75.226308, 40.025092],
#                                [-75.225191, 40.024459],
#                                [-75.223945, 40.023809],
#                                [-75.22367, 40.023633],
#                                [-75.223037, 40.023196],
#                                [-75.222205, 40.022542],
#                                [-75.221216, 40.022187],
#                                [-75.220498, 40.022026],
#                                [-75.219693, 40.02175],
#                                [-75.219583, 40.021713],
#                                [-75.219481, 40.021696],
#                                [-75.219331, 40.021671],
#                                [-75.2192388, 40.0216263],
#                                [-75.218558, 40.021296],
#                                [-75.218488, 40.021258],
#                                [-75.217344, 40.020423],
#                                [-75.216255, 40.019507],
#                                [-75.21567, 40.018886],
#                                [-75.215424, 40.018626],
#                                [-75.214663, 40.017835],
#                                [-75.214644, 40.017815],
#                                [-75.213855, 40.016914],
#                                [-75.213462, 40.016561],
#                                [-75.213386, 40.016473],
#                                [-75.213135, 40.016182],
#                                [-75.208722, 40.013349],
#                                [-75.208008, 40.012997],
#                                [-75.207728, 40.012805],
#                                [-75.207628, 40.012736],
#                                [-75.207599, 40.012719],
#                                [-75.206405, 40.012002],
#                                [-75.2057752, 40.0116551],
#                                [-75.2070544, 40.0106108],
#                                [-75.2082066, 40.0099713],
#                                [-75.2098348, 40.0090677],
#                                [-75.2107421, 40.0085968],
#                                [-75.213273, 40.0073911],
#                                [-75.2137763, 40.0071659],
#                                [-75.215055, 40.0066035],
#                                [-75.2183634, 40.0050436],
#                                [-75.2184875, 40.0049834],
#                                [-75.2187463, 40.0048614],
#                                [-75.2189355, 40.0047726],
#                                [-75.2192341, 40.0046324],
#                                [-75.2197026, 40.0044123],
#                                [-75.2198899, 40.0043245],
#                                [-75.2205689, 40.0040052],
#                                [-75.2207021, 40.0039427],
#                                [-75.2208594, 40.0038689],
#                                [-75.2209935, 40.0038057],
#                                [-75.2211935, 40.0037117],
#                                [-75.2213446, 40.0036407],
#                                [-75.2215868, 40.0035269],
#                                [-75.2221329, 40.0032702],
#                                [-75.22278, 40.002966],
#                                [-75.2230659, 40.0028316],
#                                [-75.2231392, 40.0027972],
#                                [-75.2232458, 40.002747],
#                                [-75.2235446, 40.0026064],
#                                [-75.2236334, 40.0025649],
#                                [-75.2237774, 40.0024976],
#                                [-75.224164, 40.0023167],
#                                [-75.224444, 40.0021858],
#                                [-75.2246736, 40.0020785],
#                                [-75.2256121, 40.0016395],
#                                [-75.2258835, 40.0015126],
#                                [-75.2260886, 40.0014193],
#                                [-75.2263109, 40.0013192],
#                                [-75.2264267, 40.001267],
#                                [-75.2283762, 40.0003293],
#                                [-75.2286667, 40.0001913],
#                                [-75.2287422, 40.0001555],
#                                [-75.2288061, 40.0001255],
#                                [-75.2288255, 40.0001157],
#                                [-75.2290863, 39.9999941],
#                                [-75.2291266, 39.9999753],
#                                [-75.2292703, 39.9999079],
#                                [-75.229297, 39.9998954],
#                                [-75.2294612, 39.9998185],
#                                [-75.2294957, 39.9998024],
#                                [-75.2295759, 39.9997648],
#                                [-75.2296317, 39.9997386],
#                                [-75.2765097, 39.9769692],
#                                [-75.2767495, 39.9768401],
#                                [-75.2768054, 39.9768119],
#                                [-75.2770109, 39.9767038],
#                                [-75.2773584, 39.9765208],
#                                [-75.2776948, 39.9763438],
#                                [-75.2783481, 39.976],
#                                [-75.2785717, 39.9758823],
#                                [-75.2789674, 39.9756741],
#                                [-75.2790957, 39.9755998],
#                                [-75.2792537, 39.9755193],
#                                [-75.2796234, 39.9753288],
#                                [-75.2799089, 39.9751869],
#                                [-75.2802608, 39.97502],
#                                [-75.280266, 39.974964]]],
#               'type': 'Polygon'},
#   'importance': 0.5654627750968936,
#   'lat': '40.0114538',
#   'licence': 'Data © OpenStreetMap contributors, ODbL 1.0. '
#              'http://osm.org/copyright',
#   'lon': '-75.1326504',
#   'name': 'Philadelphia County',
#   'osm_id': 417845,
#   'osm_type': 'relation',
#   'place_id': 331790929,
#   'place_rank': 12,
#   'type': 'administrative'}]

# %% [markdown]
# ### 3.1.3 Working with CSV responses
# Sometimes API responses can be in CSV format, too. For example, the schedule data API for Center City regional arrivals by SEPTA returns CSVs. Since a CSV file is really just a text file, we can read the text from the response using a CSV reader. In the output below, showing the schedule data being displayed [here](http://www3.septa.org/ccstations/30th/) in CSV format, notice that the first line and the last two lines are not part of the table, rather messages and timestamps. Further, the CSV does not appear to have been written properly in the usual one-entry-per-line format. Rather, entries for trains on the same line are joined together. Irregularities like this are easy to miss, but can end up breaking your code.

# %%
import csv
# format: "http://www3.septa.org/ccstations/STATION/sched_data.csv", acceptable values for STATION are "me", "ss", and "30th"
schedule_response = requests.get("http://www3.septa.org/ccstations/30th/sched_data.csv")
schedule_text = schedule_response.text.strip().split("\n") # removing leading and trailing spaces and splitting lines
schedule_reader = csv.reader(schedule_text)
schedule = list(schedule_reader)
pprint(schedule)
# Out:
# [["EMG=' No Emg Message"],
#  ['R4S=10:59',
#   'Airport',
#   '6',
#   ' 5 LATE',
#   'LOCAL                    ',
#   '9427  ',
#   '<_NEXT_MSG>11:29',
#   'Airport',
#   '6',
#   '18 LATE',
#   'LOCAL                    ',
#   '429   ',
#   '<_NEXT_MSG>11:59',
#   'Airport',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '9431  ',
#   '<_NEXT_MSG>12:29',
#   'Airport',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '433   ',
#   ''],
#  ['R4N=11:00',
#   'Warminster',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '424   ',
#   '<_NEXT_MSG>11:30',
#   'Temple U',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '9426  ',
#   '<_NEXT_MSG>12:00',
#   'Warminster',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '428   ',
#   '<_NEXT_MSG>12:30',
#   'Temple U',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '9430  ',
#   ''],
#  ['R2S=11:34',
#   'Marcus Hook',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '9219  ',
#   '<_NEXT_MSG>12:39',
#   'Wilmington',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '5215  ',
#   '<_NEXT_MSG>01:39',
#   'Wilmington',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '5217  ',
#   '<_NEXT_MSG>02:05',
#   '30th St Gray',
#   '',
#   'ON TIME',
#   'LOCAL                    ',
#   '6217  ',
#   ''],
#  ['R3N=11:23',
#   'West Trenton',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '6316  ',
#   '<_NEXT_MSG>11:52',
#   'Temple U',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '9316  ',
#   '<_NEXT_MSG>12:23',
#   'West Trenton',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '6320  ',
#   '<_NEXT_MSG>01:25',
#   'West Trenton',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '6324  ',
#   ''],
#  ['R3S=11:03',
#   'Wawa',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '2311  ',
#   '<_NEXT_MSG>11:32',
#   '30th St Gray',
#   '',
#   ' 5 LATE',
#   'LOCAL                    ',
#   '6313  ',
#   '<_NEXT_MSG>12:03',
#   'Wawa',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '2313  ',
#   '<_NEXT_MSG>12:32',
#   '30th St Gray',
#   '',
#   'ON TIME',
#   'LOCAL                    ',
#   '6317  ',
#   ''],
#  ['R5N=10:46',
#   'Temple U',
#   '1',
#   'ON TIME',
#   'LOCAL                    ',
#   '9544  ',
#   '<_NEXT_MSG>11:04',
#   'Doylestown',
#   '1',
#   'ON TIME',
#   'LOCAL                    ',
#   '6510  ',
#   '<_NEXT_MSG>11:15',
#   'Temple U',
#   '1',
#   '12 LATE',
#   'LOCAL                    ',
#   '9546  ',
#   '<_NEXT_MSG>12:04',
#   'Doylestown',
#   '1',
#   'ON TIME',
#   'LOCAL                    ',
#   '6512  ',
#   ''],
#  ['R5S=10:56',
#   'Malvern',
#   '4',
#   ' 1 LATE',
#   'LOCAL                    ',
#   '9513  ',
#   '<_NEXT_MSG>11:39',
#   '30th St Gray',
#   '',
#   '20 LATE',
#   'LOCAL                    ',
#   '6513  ',
#   '<_NEXT_MSG>11:56',
#   'Thorndale',
#   '4',
#   'ON TIME',
#   'LOCAL                    ',
#   '9517  ',
#   '<_NEXT_MSG>12:56',
#   'Malvern',
#   '4',
#   'ON TIME',
#   'LOCAL                    ',
#   '9521  ',
#   ''],
#  ['R2N=10:52',
#   'Norristown',
#   '5',
#   '20 LATE',
#   'LOCAL                    ',
#   '3214  ',
#   '<_NEXT_MSG>10:56',
#   'Temple U',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '9212  ',
#   '<_NEXT_MSG>11:46',
#   'Norristown',
#   '1',
#   'ON TIME',
#   'LOCAL                    ',
#   '5216  ',
#   '<_NEXT_MSG>11:57',
#   'Temple U',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '9214  ',
#   ''],
#  ['R7N=10:47',
#   'Chestnut H East',
#   '2',
#   ' 6 LATE',
#   'LOCAL                    ',
#   '708   ',
#   '<_NEXT_MSG>11:47',
#   'Chestnut H East',
#   '2',
#   'ON TIME',
#   'LOCAL                    ',
#   '710   ',
#   '<_NEXT_MSG>12:39',
#   'Chestnut H East',
#   '2',
#   'ON TIME',
#   'LOCAL                    ',
#   '712   ',
#   '<_NEXT_MSG>01:47',
#   'Chestnut H East',
#   '2',
#   'ON TIME',
#   'LOCAL                    ',
#   '714   ',
#   ''],
#  ['R7S=11:45',
#   'Trenton',
#   '3',
#   'ON TIME',
#   'LOCAL                    ',
#   '713   ',
#   '<_NEXT_MSG>12:40',
#   'Trenton',
#   '3',
#   'ON TIME',
#   'LOCAL                    ',
#   '715   ',
#   '<_NEXT_MSG>01:45',
#   'Trenton',
#   '3',
#   'ON TIME',
#   'LOCAL                    ',
#   '717   ',
#   '<_NEXT_MSG>02:45',
#   'Trenton',
#   '3',
#   'ON TIME',
#   'LOCAL                    ',
#   '719   ',
#   ''],
#  ['R8N=10:30',
#   'Fox Chase',
#   '2',
#   '19 LATE',
#   'LOCAL                    ',
#   '818   ',
#   '<_NEXT_MSG>11:00',
#   'Temple U',
#   '2',
#   ' 1 LATE',
#   'LOCAL                    ',
#   '9820  ',
#   '<_NEXT_MSG>11:30',
#   'Fox Chase',
#   '2',
#   'ON TIME',
#   'LOCAL                    ',
#   '822   ',
#   '<_NEXT_MSG>12:30',
#   'Fox Chase',
#   '2',
#   'ON TIME',
#   'LOCAL                    ',
#   '826   ',
#   ''],
#  ['R8S=11:02',
#   'Chestnut H West',
#   '3',
#   ' 2 LATE',
#   'LOCAL                    ',
#   '821   ',
#   '<_NEXT_MSG>12:02',
#   'Chestnut H West',
#   '3',
#   'ON TIME',
#   'LOCAL                    ',
#   '825   ',
#   '<_NEXT_MSG>01:02',
#   'Chestnut H West',
#   '3',
#   'ON TIME',
#   'LOCAL                    ',
#   '829   ',
#   '<_NEXT_MSG>02:02',
#   'Chestnut H West',
#   '3',
#   'ON TIME',
#   'LOCAL                    ',
#   '833   ',
#   ''],
#  ['CC-N=10:30',
#   'Fox Chase',
#   '2',
#   '19 LATE',
#   'LOCAL                    ',
#   '818   ',
#   '<_NEXT_MSG>10:47',
#   'Chestnut H East',
#   '2',
#   ' 6 LATE',
#   'LOCAL                    ',
#   '708   ',
#   '<_NEXT_MSG>10:52',
#   'Norristown',
#   '5',
#   '20 LATE',
#   'LOCAL                    ',
#   '3214  ',
#   '<_NEXT_MSG>10:56',
#   'Temple U',
#   '5',
#   'ON TIME',
#   'LOCAL                    ',
#   '9212  ',
#   ''],
#  ['CC-S=10:56',
#   'Malvern',
#   '4',
#   ' 1 LATE',
#   'LOCAL                    ',
#   '9513  ',
#   '<_NEXT_MSG>10:59',
#   'Airport',
#   '6',
#   ' 5 LATE',
#   'LOCAL                    ',
#   '9427  ',
#   '<_NEXT_MSG>11:02',
#   'Chestnut H West',
#   '3',
#   ' 2 LATE',
#   'LOCAL                    ',
#   '821   ',
#   '<_NEXT_MSG>11:03',
#   'Wawa',
#   '6',
#   'ON TIME',
#   'LOCAL                    ',
#   '2311  ',
#   ''],
#  ['SERVICE=Due to equipment shortage trains are subject to delays and '
#   'cancellation'],
#  ['TIMESTAMP=10/07/2025 10:45:02 AM']]

# %% [markdown]
# ### 3.1.4 Working with XML Responses

# %% [markdown]
# The Wikipedia API ([docs](https://en.wikipedia.org/api/rest_v1/)) returns results to various types of calls, and notably articles, in html format. Processing an html reponse into active form is more complex than JSON---the content won't necessarily translate into a native Python data type, much like XML. To work with this, we'll want to use a module called `BeautifulSoup` (install using `pip3 install bs4`), which we'll discuss in detail when we get to web scraping in __Chapter 5__. But explore, we can request the article for Philadelphia by constructing a search query and attempt to process with `xmltodict`, as introduced in __Chapter 1__.

# %%
import requests
from pprint import pprint

url = "https://en.wikipedia.org/api/rest_v1/page/html/Philadelphia Pennsylvania"

headers = {
    "User-Agent": "MyResearchBot/1.0 (contact@example.com)",  # required
    "Accept": "text/html"
}

response = requests.get(url, headers=headers)

if response.status_code == 200:
    pprint(response.text[:10000])  # print first 10k characters of the HTML
else:
    print(f"HTTP {response.status_code}: {response.text[:500]}")
# Out:
# ('<!DOCTYPE html>\n'
#  '<html prefix="dc: http://purl.org/dc/terms/ mw: http://mediawiki.org/rdf/" '
#  'about="https://en.wikipedia.org/wiki/Special:Redirect/revision/1313948242"><head '
#  'prefix="mwr: https://en.wikipedia.org/wiki/Special:Redirect/"><meta '
#  'charset="utf-8"/><meta property="mw:pageId" content="50585"/><meta '
#  'property="mw:pageNamespace" content="0"/><link rel="dc:replaces" '
#  'resource="mwr:revision/1311797888"/><meta property="mw:revisionSHA1" '
#  'content="524521b1c486ae1d9cf15f6423d00a98e57e19d0"/><meta '
#  'property="dc:modified" content="2025-09-28T23:36:32.000Z"/><meta '
#  'property="mw:htmlVersion" content="2.8.0"/><meta property="mw:html:version" '
#  'content="2.8.0"/><link rel="dc:isVersionOf" '
#  'href="//en.wikipedia.org/wiki/Philadelphia"/><base '
#  'href="//en.wikipedia.org/wiki/"/><title>Philadelphia</title><meta '
#  'property="mw:jsConfigVars" '
#  'content=\'{"wgKartographerLiveData":{"_df0de172ae4b745c346ccfa3fd25bd2e1de4d37b":[{"type":"ExternalData","service":"geoshape","url":"https://maps.wikimedia.org/geoshape?getgeojson=1&amp;ids=Q1345","properties":{"title":"Philadelphia","fill-opacity":0.5,"stroke":"#FF0000","stroke-width":3,"fill":"#606060"}},{"type":"ExternalData","service":"geoline","url":"https://maps.wikimedia.org/geoline?getgeojson=1&amp;ids=Q1345","properties":{"stroke-width":5,"stroke":"#FF0000","title":"Philadelphia"}}]}}\'/><meta '
#  'property="mw:generalModules" '
#  'content="ext.kartographer.staticframe|ext.phonos.init|mediawiki.page.gallery|ext.cite.ux-enhancements|mediawiki.page.media"/><meta '
#  'property="mw:moduleStyles" '
#  'content="ext.phonos.styles|ext.phonos.icons|mediawiki.page.gallery.styles|ext.cite.parsoid.styles|ext.cite.styles|ext.kartographer.style"/><link '
#  'rel="stylesheet" '
#  'href="/w/load.php?lang=en&amp;modules=ext.phonos.styles%7Cext.phonos.icons%7Cmediawiki.page.gallery.styles%7Cext.cite.parsoid.styles%7Cext.cite.styles%7Cext.kartographer.style%7Cmediawiki.skinning.content.parsoid%7Cmediawiki.skinning.interface%7Csite.styles&amp;only=styles&amp;skin=vector"/><meta '
#  'http-equiv="content-language" content="en"/><meta http-equiv="vary" '
#  'content="Accept"/></head><body lang="en" class="mw-content-ltr sitedir-ltr '
#  'ltr mw-body-content parsoid-body mediawiki mw-parser-output" dir="ltr" '
#  'data-mw-parsoid-version="0.22.0.0-alpha25" data-mw-html-version="2.8.0" '
#  'id="mwAA"><section data-mw-section-id="0" id="mwAQ"><div '
#  'class="shortdescription nomobile noexcerpt noprint searchaux" '
#  'style="display:none" about="#mwt1" typeof="mw:Transclusion" '
#  'data-mw=\'{"parts":[{"template":{"target":{"wt":"Short '
#  'description","href":"./Template:Short_description"},"params":{"1":{"wt":"Largest '
#  'city in Pennsylvania, United States"}},"i":0}}]}\' id="mwAg">Largest city in '
#  'Pennsylvania, United States</div><link rel="mw:PageProp/Category" '
#  'href="./Category:Articles_with_short_description" about="#mwt1"/><link '
#  'rel="mw:PageProp/Category" '
#  'href="./Category:Short_description_matches_Wikidata" about="#mwt1" '
#  'id="mwAw"/>\n'
#  '<style data-mw-deduplicate="TemplateStyles:r1236090951" '
#  'typeof="mw:Extension/templatestyles mw:Transclusion" about="#mwt2" '
#  'data-mw=\'{"name":"templatestyles","attrs":{"src":"Module:Hatnote/styles.css"},"body":{"extsrc":""},"parts":[{"template":{"target":{"wt":"Hatnote '
#  'group","href":"./Template:Hatnote_group"},"params":{"1":{"wt":"\\n{{Redirect-distinguish|Philly|Filly|Filadelfia|Philadelphi}}\\n{{Other '
#  'uses|Philly (disambiguation)||Philadelphia '
#  '(disambiguation)}}\\n"}},"i":0}}]}\' id="mwBA">.mw-parser-output '
#  '.hatnote{font-style:italic}.mw-parser-output '
#  'div.hatnote{padding-left:1.6em;margin-bottom:0.5em}.mw-parser-output '
#  '.hatnote i{font-style:normal}.mw-parser-output '
#  '.hatnote+link+.hatnote{margin-top:-0.5em}@media print{body.ns-0 '
#  '.mw-parser-output .hatnote{display:none!important}}</style><div role="note" '
#  'class="hatnote navigation-not-searchable " about="#mwt2" '
#  'id="mwBQ"><span>"Philly" redirects here; not to be confused with <a '
#  'rel="mw:WikiLink" href="./Filly" title="Filly">Filly</a>, <a '
#  'rel="mw:WikiLink" href="./Filadelfia" title="Filadelfia">Filadelfia</a>, or '
#  '<a rel="mw:WikiLink" href="./Philadelphi" title="Philadelphi" '
#  'class="mw-redirect">Philadelphi</a>.</span> <span>For other uses, see <a '
#  'rel="mw:WikiLink" href="./Philly_(disambiguation)" title="Philly '
#  '(disambiguation)" class="mw-disambig">Philly (disambiguation)</a> and <a '
#  'rel="mw:WikiLink" href="./Philadelphia_(disambiguation)" title="Philadelphia '
#  '(disambiguation)" class="mw-disambig">Philadelphia '
#  '(disambiguation)</a>.</span></div>\n'
#  '<p class="mw-empty-elt" id="mwBg"><span typeof="mw:Nowiki mw:Transclusion" '
#  'about="#mwt4" '
#  'data-mw=\'{"parts":[{"template":{"target":{"wt":"Pp-semi-indef","href":"./Template:Pp-semi-indef"},"params":{},"i":0}}]}\' '
#  'id="mwBw"></span><meta typeof="mw:Extension/indicator" about="#mwt4" '
#  'data-mw=\'{"name":"indicator","attrs":{"name":"pp-default"},"body":{"extsrc":"[[File:Semi-protection-shackle.svg|20px|link=Wikipedia:Protection '
#  'policy#semi|alt=Page semi-protected|This article is '
#  'semi-protected.]]"},"html":"&lt;span typeof=\\"mw:File\\" '
#  'data-mw=&apos;{\\"caption\\":\\"This article is semi-protected.\\"}&apos; '
#  'id=\\"mwCA\\">&lt;a href=\\"./Wikipedia:Protection_policy#semi\\" '
#  'title=\\"This article is semi-protected.\\" id=\\"mwCQ\\">&lt;img '
#  'alt=\\"Page semi-protected\\" '
#  'resource=\\"./File:Semi-protection-shackle.svg\\" '
#  'src=\\"//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png\\" '
#  'decoding=\\"async\\" data-file-width=\\"512\\" data-file-height=\\"512\\" '
#  'data-file-type=\\"drawing\\" height=\\"20\\" width=\\"20\\" '
#  'srcset=\\"//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/40px-Semi-protection-shackle.svg.png '
#  '1.5x, '
#  '//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/40px-Semi-protection-shackle.svg.png '
#  '2x\\" class=\\"mw-file-element\\" id=\\"mwCg\\"/>&lt;/a>&lt;/span>"}\' '
#  'id="mwCw"/><link rel="mw:PageProp/Category" '
#  'href="./Category:Wikipedia_indefinitely_semi-protected_pages#Philadelphia" '
#  'about="#mwt4" id="mwDA"/>\n'
#  '<link rel="mw:PageProp/Category" '
#  'href="./Category:Wikipedia_indefinitely_move-protected_pages#Philadelphia" '
#  'about="#mwt6" typeof="mw:Transclusion" '
#  'data-mw=\'{"parts":[{"template":{"target":{"wt":"Pp-move","href":"./Template:Pp-move"},"params":{},"i":0}}]}\' '
#  'id="mwDQ"/>\n'
#  '<span typeof="mw:Nowiki mw:Transclusion" about="#mwt7" '
#  'data-mw=\'{"parts":[{"template":{"target":{"wt":"Use American '
#  'English","href":"./Template:Use_American_English"},"params":{"date":{"wt":"June '
#  '2025"}},"i":0}}]}\' id="mwDg"></span><link rel="mw:PageProp/Category" '
#  'href="./Category:Use_American_English_from_June_2025" about="#mwt7"/><link '
#  'rel="mw:PageProp/Category" '
#  'href="./Category:All_Wikipedia_articles_written_in_American_English" '
#  'about="#mwt7" id="mwDw"/>\n'
#  '<span typeof="mw:Nowiki mw:Transclusion" about="#mwt8" '
#  'data-mw=\'{"parts":[{"template":{"target":{"wt":"Use mdy '
#  'dates","href":"./Template:Use_mdy_dates"},"params":{"date":{"wt":"November '
#  '2023"}},"i":0}}]}\' id="mwEA"></span><link rel="mw:PageProp/Category" '
#  'href="./Category:Use_mdy_dates_from_November_2023" about="#mwt8" '
#  'id="mwEQ"/></p>\n'
#  '<div class="shortdescription nomobile noexcerpt noprint searchaux" '
#  'style="display:none" about="#mwt9" typeof="mw:Transclusion" '
#  'data-mw=\'{"parts":[{"template":{"target":{"wt":"Infobox '
#  'settlement\\n","href":"./Template:Infobox_settlement"},"params":{"name":{"wt":"Philadelphia"},"settlement_type":{"wt":"[[Consolidated '
#  'city-county]]"},"etymology":{"wt":"[[Ancient Greek]] '
#  '{{lang|grc|[[wikt:φίλος|φίλος]]}} {{Transliteration|grc|phílos}} '
#  '(&apos;beloved, dear&apos;) and {{lang|grc|[[wikt:ἀδελφός|ἀδελφός]]}} '
#  '{{Transliteration|grc|adelphós}} (&apos;brother, '
#  'brotherly&apos;)"},"image_skyline":{"wt":"{{multiple image\\n '
#  '|border             = infobox\\n |total_width        = 290\\n '
#  '|perrow             = 1/2/2/1\\n |caption_align      = center\\n '
#  '|image1             = Philadelphia skyline from South Street Bridge January '
#  '2020 (rotate 2 degrees perspective correction crop 4-1).jpg\\n '
#  '|alt1               = Skyline of Center City\\n |caption1           = '
#  'Skyline of [[Center City (Philadelphia)|Center City]]\\n |image2             '
#  '= Independence National Historical Park INDE0004 b.jpg\\n '
#  '|alt2               = Independence National Historical Park\\n '
#  '|caption2           = [[Independence National Historical Park]]\\n '
#  '|image3             = Philadelphia City Hall, aerial view, cropped.png\\n '
#  '|alt3               = Philadelphia City Hall\\n |caption3           = '
#  '[[Philadelphia City Hall]] \\n |image4             = '
#  'Silverliner_V_SEPTA-811-philadelphia-22-6-2012-fws.jpg\\n '
#  '|alt4               = Train in station\\n |caption4           = [[SEPTA]] '
#  'Rail\\n |image5             = Elfreth&apos;s Alley (53572700168).jpg\\n '
#  '|alt5               = Elfreth&apos;s Alley\\n |caption5           = '
#  '[[Elfreth&apos;s Alley]]\\n |image6             = '
#  'PhiladelphiaMuseumOfArt2017.jpg\\n |alt6               = Philadelphia Museum '
#  'of Art\\n |caption6           = [[Philadelphia Museum of '
#  'Art]]\\n}}"},"nickname":{"wt":"\\"Philly\\", \\"The City of Brotherly '
#  'Love\\", [[Nicknames of '
#  'Philadelphia|others]]"},"motto":{"wt":"\\"Philadelphia maneto\\" (\\"Let '
#  'brotherly love endure\\" or \\"... continue\\")&lt;ref>{{cite web '
#  '|last=Robinson |first=Sam |date=November 5, 2013 '
#  '|url=https://hiddencityphila.org/2013/11/behind-philadelphia-maneto-dissecting-the-city-seal '
#  '|title=Behind Philadelphia Maneto: Dissecting The City Seal |website=Hidden '
#  'City Philadelphia |access-date=January 18, 2018 |archive-date=January 19, '
#  '2018 '
#  '|archive-url=https://web.archive.org/web/20180119040015/https://hiddencityphila.org/2013/11/behind-philadelphia-maneto-dissecting-the-city-seal/ '
#  '|url-status=live }}&lt;/ref>&lt;ref>{{cite web |last=McDevitt |first=John '
#  '|date=May 5, 2015 '
#  '|url=http://philadelphia.cbslocal.com/2015/05/05/plaque-dedication-marks-120th-anniversary-of-creation-of-philadelphias-flag/ '
#  '|title=Plaque Dedication Marks 120th Anniversary of Creation of '
#  'Philadelphia&apos;s Flag |publisher=CBS Broadcasting Inc. '
#  '|access-date=January 18, 2018 |archive-date=January 19, 2018 '
#  '|archive-url=https://web.archive.org/web/20180119035613/http://philadelphia.cbslocal.com/2015/05/05/plaque-dedication-marks')

# %% [markdown]
# Since html is essentially a type of XML, we can try and convert the response into a dictionary using `xmltodict`. As you can see, in order to get the desired data out of the html, some studying of its structure is necessary. And since the structure of an html document is so particular, it will turn out to be a bit easier working with the html-specific parser in `BeautifulSoup` (__Chapter 5__). However, as we can see the content is there and navigable!

# %%
import xmltodict

parsed = xmltodict.parse(response.text)
pprint(parsed['html']['body']['section'][0])
# Out:
# {'@data-mw-section-id': '0',
#  '@id': 'mwAQ',
#  'div': [{'#text': 'Largest city in Pennsylvania, United States',
#           '@about': '#mwt1',
#           '@class': 'shortdescription nomobile noexcerpt noprint searchaux',
#           '@data-mw': '{"parts":[{"template":{"target":{"wt":"Short '
#                       'description","href":"./Template:Short_description"},"params":{"1":{"wt":"Largest '
#                       'city in Pennsylvania, United States"}},"i":0}}]}',
#           '@id': 'mwAg',
#           '@style': 'display:none',
#           '@typeof': 'mw:Transclusion'},
#          {'@about': '#mwt2',
#           '@class': 'hatnote navigation-not-searchable ',
#           '@id': 'mwBQ',
#           '@role': 'note',
#           'span': [{'#text': '"Philly" redirects here; not to be confused with '
#                              ', , or .',
#                     'a': [{'#text': 'Filly',
#                            '@href': './Filly',
#                            '@rel': 'mw:WikiLink',
#                            '@title': 'Filly'},
#                           {'#text': 'Filadelfia',
#                            '@href': './Filadelfia',
#                            '@rel': 'mw:WikiLink',
#                            '@title': 'Filadelfia'},
#                           {'#text': 'Philadelphi',
#                            '@class': 'mw-redirect',
#                            '@href': './Philadelphi',
#                            '@rel': 'mw:WikiLink',
#                            '@title': 'Philadelphi'}]},
#                    {'#text': 'For other uses, see  and .',
#                     'a': [{'#text': 'Philly (disambiguation)',
#                            '@class': 'mw-disambig',
#                            '@href': './Philly_(disambiguation)',
#                            '@rel': 'mw:WikiLink',
#                            '@title': 'Philly (disambiguation)'},
#                           {'#text': 'Philadelphia (disambiguation)',
#                            '@class': 'mw-disambig',
#                            '@href': './Philadelphia_(disambiguation)',
#                            '@rel': 'mw:WikiLink',
#                            '@title': 'Philadelphia (disambiguation)'}]}]},
#          {'#text': 'Consolidated city-county in the United States',
#           '@about': '#mwt9',
#           '@class': 'shortdescription nomobile noexcerpt noprint searchaux',
#           '@data-mw': '{"parts":[{"template":{"target":{"wt":"Infobox '
#                       'settlement\\n","href":"./Template:Infobox_settlement"},"params":{"name":{"wt":"Philadelphia"},"settlement_type":{"wt":"[[Consolidated '
#                       'city-county]]"},"etymology":{"wt":"[[Ancient Greek]] '
#                       '{{lang|grc|[[wikt:φίλος|φίλος]]}} '
#                       "{{Transliteration|grc|phílos}} ('beloved, dear') and "
#                       '{{lang|grc|[[wikt:ἀδελφός|ἀδελφός]]}} '
#                       "{{Transliteration|grc|adelphós}} ('brother, "
#                       'brotherly\')"},"image_skyline":{"wt":"{{multiple '
#                       'image\\n |border             = infobox\\n '
#                       '|total_width        = 290\\n |perrow             = '
#                       '1/2/2/1\\n |caption_align      = center\\n '
#                       '|image1             = Philadelphia skyline from South '
#                       'Street Bridge January 2020 (rotate 2 degrees '
#                       'perspective correction crop 4-1).jpg\\n '
#                       '|alt1               = Skyline of Center City\\n '
#                       '|caption1           = Skyline of [[Center City '
#                       '(Philadelphia)|Center City]]\\n |image2             = '
#                       'Independence National Historical Park INDE0004 b.jpg\\n '
#                       '|alt2               = Independence National Historical '
#                       'Park\\n |caption2           = [[Independence National '
#                       'Historical Park]]\\n |image3             = Philadelphia '
#                       'City Hall, aerial view, cropped.png\\n '
#                       '|alt3               = Philadelphia City Hall\\n '
#                       '|caption3           = [[Philadelphia City Hall]] \\n '
#                       '|image4             = '
#                       'Silverliner_V_SEPTA-811-philadelphia-22-6-2012-fws.jpg\\n '
#                       '|alt4               = Train in station\\n '
#                       '|caption4           = [[SEPTA]] Rail\\n '
#                       "|image5             = Elfreth's Alley "
#                       "(53572700168).jpg\\n |alt5               = Elfreth's "
#                       "Alley\\n |caption5           = [[Elfreth's Alley]]\\n "
#                       '|image6             = '
#                       'PhiladelphiaMuseumOfArt2017.jpg\\n |alt6               '
#                       '= Philadelphia Museum of Art\\n |caption6           = '
#                       '[[Philadelphia Museum of '
#                       'Art]]\\n}}"},"nickname":{"wt":"\\"Philly\\", \\"The '
#                       'City of Brotherly Love\\", [[Nicknames of '
#                       'Philadelphia|others]]"},"motto":{"wt":"\\"Philadelphia '
#                       'maneto\\" (\\"Let brotherly love endure\\" or \\"... '
#                       'continue\\")<ref>{{cite web |last=Robinson |first=Sam '
#                       '|date=November 5, 2013 '
#                       '|url=https://hiddencityphila.org/2013/11/behind-philadelphia-maneto-dissecting-the-city-seal '
#                       '|title=Behind Philadelphia Maneto: Dissecting The City '
#                       'Seal |website=Hidden City Philadelphia '
#                       '|access-date=January 18, 2018 |archive-date=January 19, '
#                       '2018 '
#                       '|archive-url=https://web.archive.org/web/20180119040015/https://hiddencityphila.org/2013/11/behind-philadelphia-maneto-dissecting-the-city-seal/ '
#                       '|url-status=live }}</ref><ref>{{cite web |last=McDevitt '
#                       '|first=John |date=May 5, 2015 '
#                       '|url=http://philadelphia.cbslocal.com/2015/05/05/plaque-dedication-marks-120th-anniversary-of-creation-of-philadelphias-flag/ '
#                       '|title=Plaque Dedication Marks 120th Anniversary of '
#                       "Creation of Philadelphia's Flag |publisher=CBS "
#                       'Broadcasting Inc. |access-date=January 18, 2018 '
#                       '|archive-date=January 19, 2018 '
#                       '|archive-url=https://web.archive.org/web/20180119035613/http://philadelphia.cbslocal.com/2015/05/05/plaque-dedication-marks-120th-anniversary-of-creation-of-philadelphias-flag/ '
#                       '|url-status=live }}</ref>"},"image_flag":{"wt":"Flag of '
#                       'Philadelphia, '
#                       'Pennsylvania.svg"},"image_seal":{"wt":"Seal of '
#                       'Philadelphia, '
#                       'Pennsylvania.svg"},"image_blank_emblem":{"wt":"City of '
#                       'Philadelphia '
#                       'Logo.svg"},"blank_emblem_size":{"wt":"150px"},"blank_emblem_type":{"wt":"Logo"},"image_map":{"wt":"{{infobox '
#                       'mapframe|frame=yes|plain=y|frame-width=250|frame-height=300|zoom=8|frame-lat=39.953|frame-long=-75.164|type=shape-inverse|id=Q1345| '
#                       'title=Philadelphia}}"},"mapsize":{"wt":""},"map_caption":{"wt":"Interactive '
#                       'map outlining '
#                       'Philadelphia"},"pushpin_map":{"wt":"Pennsylvania#USA#North '
#                       'America#Earth"},"pushpin_relief":{"wt":"yes"},"pushpin_label_position":{"wt":"left"},"pushpin_label":{"wt":"{{nowrap|Philadelphia}}"},"pushpin_map_caption":{"wt":"Location '
#                       'within the [[state of Pennsylvania]]##Location within '
#                       'the United States ##Location in North America##Location '
#                       'on '
#                       'Earth"},"coordinates":{"wt":"{{Wikidatacoord|Q1345|region:US-PA_type:city|display=inline,title}}"},"subdivision_type":{"wt":"[[List '
#                       'of sovereign '
#                       'states|Country]]"},"subdivision_type2":{"wt":"[[U.S. '
#                       'state|State]]"},"subdivision_type3":{"wt":"[[List of '
#                       'counties in '
#                       'Pennsylvania|County]]"},"subdivision_name":{"wt":"{{USA}}"},"subdivision_name2":{"wt":"{{flag|Pennsylvania}}"},"subdivision_name3":{"wt":"[[Philadelphia '
#                       'County, '
#                       'Pennsylvania|Philadelphia]]"},"subdivision_type4":{"wt":"Historic '
#                       'countries"},"subdivision_name4":{"wt":"[[Kingdom of '
#                       'England]]<br />[[Kingdom of Great Britain]]<br '
#                       '/>Netherlands<br />Sweden<br '
#                       '/>[[Lenape]]"},"subdivision_type5":{"wt":"[[Colony|Historic '
#                       'colony]]"},"subdivision_name5":{"wt":"[[Province of '
#                       'Pennsylvania]]"},"government_type":{"wt":"[[Mayor–council '
#                       'government|Mayor–council]], [[consolidated '
#                       'city-county]]"},"governing_body":{"wt":"[[Philadelphia '
#                       'City Council]]"},"leader_title":{"wt":"[[List of mayors '
#                       'of '
#                       'Philadelphia|Mayor]]"},"leader_name":{"wt":"[[Cherelle '
#                       'Parker]] ([[Democratic Party (United '
#                       'States)|D]])"},"established_title":{"wt":"Founded"},"established_title1":{"wt":"[[Municipal '
#                       'corporation|Incorporated]]"},"established_date":{"wt":"{{Start '
#                       'date and age|1682}}<ref name=weigley/><!-- ref states '
#                       'early 1862 for first land purchase and summer 1682 for '
#                       "initial survey by Penn's surveyor-general, Thomas "
#                       "Holme, before Penn's arrival in October; no exact dates "
#                       'are given -->"},"established_date1":{"wt":"October 25, '
#                       '1701"},"founder":{"wt":"[[William '
#                       'Penn]]"},"unit_pref":{"wt":"Imperial"},"area_total_sq_mi":{"wt":"142.70"},"area_total_km2":{"wt":"369.59"},"area_land_sq_mi":{"wt":"134.36"},"area_land_km2":{"wt":"347.98"},"area_water_sq_mi":{"wt":"8.34"},"area_water_km2":{"wt":"21.61"},"area_footnotes":{"wt":"<ref '
#                       'name=\\"TigerWebMapServer\\">{{cite web |title=ArcGIS '
#                       'REST Services Directory '
#                       '|url=https://tigerweb.geo.census.gov/arcgis/rest/services/TIGERweb/Places_CouSub_ConCity_SubMCD/MapServer/5/query?where=STATE%3D%2742%27&outFields=NAME%2CSTATE%2CPLACE%2CAREALAND%2CAREAWATER%2CLSADC%2CCENTLAT%2CCENTLON&orderByFields=PLACE&returnGeometry=false&returnTrueCurves=false&f=json '
#                       '|publisher=United States Census Bureau '
#                       '|access-date=October 16, 2022 |archive-date=November 9, '
#                       '2022 '
#                       '|archive-url=https://web.archive.org/web/20221109154513/https://tigerweb.geo.census.gov/arcgis/rest/services/TIGERweb/Places_CouSub_ConCity_SubMCD/MapServer/5/query?where=STATE%3D%2742%27&outFields=NAME%2CSTATE%2CPLACE%2CAREALAND%2CAREAWATER%2CLSADC%2CCENTLAT%2CCENTLON&orderByFields=PLACE&returnGeometry=false&returnTrueCurves=false&f=json '
#                       '|url-status=live '
#                       '}}</ref>"},"population_as_of":{"wt":"[[2020 United '
#                       'States '
#                       'census|2020]]"},"population_footnotes":{"wt":"<ref '
#                       'name=\\"USCensusDecennial2020CenPopScriptOnly\\">{{cite '
#                       'web '
#                       '|url=https://api.census.gov/data/2020/dec/pl?get=P1_001N,NAME&for=place:*&in=state:42&key=5ccd0821c15d9f4520e2dcc0f8d92b2ec9336108 '
#                       '|title=Census Population API |publisher=United States '
#                       'Census Bureau |access-date=October 16, 2022 '
#                       '|archive-date=November 9, 2022 '
#                       '|archive-url=https://web.archive.org/web/20221109154513/https://api.census.gov/data/2020/dec/pl?get=P1_001N,NAME&for=place:*&in=state:42&key=5ccd0821c15d9f4520e2dcc0f8d92b2ec9336108 '
#                       '|url-status=live '
#                       '}}</ref>"},"population_total":{"wt":"1,603,797"},"population_est":{"wt":"1,573,916"},"pop_est_as_of":{"wt":"2024"},"pop_est_footnotes":{"wt":"<ref '
#                       'name=\\"Estimate2024\\">{{cite web |title=Census '
#                       'QuickFacts Philadelphia '
#                       '|url=https://www.census.gov/quickfacts/fact/table/philadelphiacountypennsylvania/PST045224 '
#                       '|website=census.gov |access-date=March 15, '
#                       '2025}}</ref>"},"population_rank":{"wt":"[[List of North '
#                       'American cities by population|13th]] in North '
#                       'America<br />[[List of United States cities by '
#                       'population|6th]] in the United States<br />[[List of '
#                       'municipalities in Pennsylvania|1st]] in '
#                       'Pennsylvania"},"population_metro_footnotes":{"wt":"<ref '
#                       'name=\\"2020Pop\\">{{cite web |title=2020 Population '
#                       'and Housing State Data '
#                       '|url=https://www.census.gov/library/visualizations/interactive/2020-population-and-housing-state-data.html '
#                       '|publisher=United States Census Bureau '
#                       '|access-date=August 22, 2021 |archive-date=August 24, '
#                       '2021 '
#                       '|archive-url=https://web.archive.org/web/20210824081449/https://www.census.gov/library/visualizations/interactive/2020-population-and-housing-state-data.html '
#                       '|url-status=live '
#                       '}}</ref>"},"population_metro":{"wt":"6245051 (US: '
#                       '[[List of metropolitan statistical '
#                       'areas|9th]])"},"population_density_sq_mi":{"wt":"11936.92"},"population_density_km2":{"wt":"4608.86"},"population_urban":{"wt":"5,696,125 '
#                       '(US: [[List of United States urban '
#                       'areas|7th]])"},"population_density_urban_km2":{"wt":"1,158.6"},"population_density_urban_sq_mi":{"wt":"3,000.8"},"population_urban_footnotes":{"wt":"<ref '
#                       'name=\\"urban area\\">{{cite web '
#                       '|url=https://www.census.gov/programs-surveys/geography/guidance/geo-areas/urban-rural.html '
#                       '|title=List of 2020 Census Urban Areas '
#                       '|website=census.gov |publisher=United States Census '
#                       'Bureau |access-date=January 8, 2023 '
#                       '|archive-date=January 14, 2023 '
#                       '|archive-url=https://web.archive.org/web/20230114022812/https://www.census.gov/programs-surveys/geography/guidance/geo-areas/urban-rural.html '
#                       '|url-status=live '
#                       '}}</ref>"},"population_demonym":{"wt":"Philadelphian"},"demographics_type2":{"wt":"GDP"},"demographics2_footnotes":{"wt":"<ref '
#                       'name=PhiladelphiaMetroGDP>{{Cite web |title=Total Gross '
#                       'Domestic Product for Philadelphia-Camden-Wilmington, '
#                       'PA-NJ-DE-MD (MSA) '
#                       '|url=https://fred.stlouisfed.org/series/NGMP37980 '
#                       '|website=fred.stlouisfed.org |access-date=January 3, '
#                       '2024 |archive-date=January 10, 2024 '
#                       '|archive-url=https://web.archive.org/web/20240110135225/https://fred.stlouisfed.org/series/NGMP37980 '
#                       '|url-status=live '
#                       '}}</ref>"},"demographics2_title1":{"wt":"Philadelphia '
#                       '(MSA)"},"demographics2_info1":{"wt":"$518.5 billion '
#                       '(2022)"},"timezone":{"wt":"[[North American Eastern '
#                       'Time '
#                       'Zone|EST]]"},"utc_offset":{"wt":"−5"},"timezone_DST":{"wt":"[[Eastern '
#                       'Daylight '
#                       'Time|EDT]]"},"utc_offset_DST":{"wt":"−4"},"postal_code_type":{"wt":"[[ZIP '
#                       'Code]]s"},"postal_code":{"wt":"19092–19093, 19099, '
#                       '191xx"},"area_codes":{"wt":"[[Area codes 215, 267, and '
#                       '445|215, 267, '
#                       '445]]"},"elevation_m":{"wt":"12"},"elevation_ft":{"wt":"39"},"blank_name":{"wt":"[[Federal '
#                       'Information Processing Standards|FIPS '
#                       'code]]"},"blank_info":{"wt":"42-60000"},"blank1_name":{"wt":"[[Geographic '
#                       'Names Information System|GNIS]] feature '
#                       'ID"},"blank1_info":{"wt":"1215531<ref>{{cite web '
#                       '|url=http://geonames.usgs.gov/apex/f?p=136:3:0::NO::P3_FID,P3_TITLE:1215531,City%20of%20Philadelphia '
#                       '|access-date=January 31, 2008 |title=US Board on '
#                       'Geographic Names |publisher=[[United States Geological '
#                       'Survey]] |date=February 2, 2015 |archive-date=October '
#                       '27, 2023 '
#                       '|archive-url=https://web.archive.org/web/20231027140852/https://www.usgs.gov/us-board-on-geographic-names/domestic-names?p=136%3A3%3A0%3A%3ANO%3A%3AP3_FID%2CP3_TITLE%3A1215531%2CCity%2520of%2520Philadelphia '
#                       '|url-status=live }}</ref>"},"website":{"wt":"{{official '
#                       'URL}}"}},"i":0}}]}',
#           '@id': 'mwEg',
#           '@style': 'display:none',
#           '@typeof': 'mw:Transclusion'},
#          {'@about': '#mwt156',
#           '@class': 'toclimit-3',
#           '@id': 'mwATw',
#           'meta': {'@property': 'mw:PageProp/toc'}}],
#  'link': [{'@about': '#mwt1',
#            '@href': './Category:Articles_with_short_description',
#            '@rel': 'mw:PageProp/Category'},
#           {'@about': '#mwt1',
#            '@href': './Category:Short_description_matches_Wikidata',
#            '@id': 'mwAw',
#            '@rel': 'mw:PageProp/Category'},
#           {'@about': '#mwt9',
#            '@href': './Category:Articles_with_short_description',
#            '@rel': 'mw:PageProp/Category'},
#           {'@about': '#mwt9',
#            '@href': './Category:Short_description_is_different_from_Wikidata',
#            '@rel': 'mw:PageProp/Category'}],
#  'p': [{'@class': 'mw-empty-elt',
#         '@id': 'mwBg',
#         'link': [{'@about': '#mwt4',
#                   '@href': './Category:Wikipedia_indefinitely_semi-protected_pages#Philadelphia',
#                   '@id': 'mwDA',
#                   '@rel': 'mw:PageProp/Category'},
#                  {'@about': '#mwt6',
#                   '@data-mw': '{"parts":[{"template":{"target":{"wt":"Pp-move","href":"./Template:Pp-move"},"params":{},"i":0}}]}',
#                   '@href': './Category:Wikipedia_indefinitely_move-protected_pages#Philadelphia',
#                   '@id': 'mwDQ',
#                   '@rel': 'mw:PageProp/Category',
#                   '@typeof': 'mw:Transclusion'},
#                  {'@about': '#mwt7',
#                   '@href': './Category:Use_American_English_from_June_2025',
#                   '@rel': 'mw:PageProp/Category'},
#                  {'@about': '#mwt7',
#                   '@href': './Category:All_Wikipedia_articles_written_in_American_English',
#                   '@id': 'mwDw',
#                   '@rel': 'mw:PageProp/Category'},
#                  {'@about': '#mwt8',
#                   '@href': './Category:Use_mdy_dates_from_November_2023',
#                   '@id': 'mwEQ',
#                   '@rel': 'mw:PageProp/Category'}],
#         'meta': {'@about': '#mwt4',
#                  '@data-mw': '{"name":"indicator","attrs":{"name":"pp-default"},"body":{"extsrc":"[[File:Semi-protection-shackle.svg|20px|link=Wikipedia:Protection '
#                              'policy#semi|alt=Page semi-protected|This article '
#                              'is semi-protected.]]"},"html":"<span '
#                              'typeof=\\"mw:File\\" '
#                              'data-mw=\'{\\"caption\\":\\"This article is '
#                              'semi-protected.\\"}\' id=\\"mwCA\\"><a '
#                              'href=\\"./Wikipedia:Protection_policy#semi\\" '
#                              'title=\\"This article is semi-protected.\\" '
#                              'id=\\"mwCQ\\"><img alt=\\"Page semi-protected\\" '
#                              'resource=\\"./File:Semi-protection-shackle.svg\\" '
#                              'src=\\"//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/20px-Semi-protection-shackle.svg.png\\" '
#                              'decoding=\\"async\\" data-file-width=\\"512\\" '
#                              'data-file-height=\\"512\\" '
#                              'data-file-type=\\"drawing\\" height=\\"20\\" '
#                              'width=\\"20\\" '
#                              'srcset=\\"//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/40px-Semi-protection-shackle.svg.png '
#                              '1.5x, '
#                              '//upload.wikimedia.org/wikipedia/en/thumb/1/1b/Semi-protection-shackle.svg/40px-Semi-protection-shackle.svg.png '
#                              '2x\\" class=\\"mw-file-element\\" '
#                              'id=\\"mwCg\\"/></a></span>"}',
#                  '@id': 'mwCw',
#                  '@typeof': 'mw:Extension/indicator'},
#         'span': [{'@about': '#mwt4',
#                   '@data-mw': '{"parts":[{"template":{"target":{"wt":"Pp-semi-indef","href":"./Template:Pp-semi-indef"},"params":{},"i":0}}]}',
#                   '@id': 'mwBw',
#                   '@typeof': 'mw:Nowiki mw:Transclusion'},
#                  {'@about': '#mwt7',
#                   '@data-mw': '{"parts":[{"template":{"target":{"wt":"Use '
#                               'American '
#                               'English","href":"./Template:Use_American_English"},"params":{"date":{"wt":"June '
#                               '2025"}},"i":0}}]}',
#                   '@id': 'mwDg',
#                   '@typeof': 'mw:Nowiki mw:Transclusion'},
#                  {'@about': '#mwt8',
#                   '@data-mw': '{"parts":[{"template":{"target":{"wt":"Use mdy '
#                               'dates","href":"./Template:Use_mdy_dates"},"params":{"date":{"wt":"November '
#                               '2023"}},"i":0}}]}',
#                   '@id': 'mwEA',
#                   '@typeof': 'mw:Nowiki mw:Transclusion'}]},
#        {'#text': '( ), colloquially referred to as , is the  in the U.S. state '
#                  'of . It is the  with a population of 1.6 million at the , '
#                  'while the Philadelphia metropolitan area (sometimes called '
#                  "the ) with 6.33 million residents is the nation's . "
#                  'Philadelphia is known for , , and , maintaining contemporary '
#                  'influence in , culture, sports, and music.',
#         '@id': 'mwWA',
#         'a': [{'@about': '#mwt53',
#                '@data-mw': '{"parts":[{"template":{"target":{"wt":"Respell","href":"./Template:Respell"},"params":{"1":{"wt":"FIL"},"2":{"wt":"ə"},"3":{"wt":"DEL"},"4":{"wt":"fee"},"5":{"wt":"ə"}},"i":0}}]}',
#                '@href': './Help:Pronunciation_respelling_key',
#                '@id': 'mwXA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Help:Pronunciation respelling key',
#                '@typeof': 'mw:Transclusion',
#                'i': {'#text': '-ə--fee-ə',
#                      '@title': 'English pronunciation respelling',
#                      'span': [{'#text': 'FIL', '@style': 'font-size:90%'},
#                               {'#text': 'DEL', '@style': 'font-size:90%'}]}},
#               {'#text': 'most populous city',
#                '@href': './List_of_municipalities_in_Pennsylvania',
#                '@id': 'mwXg',
#                '@rel': 'mw:WikiLink',
#                '@title': 'List of municipalities in Pennsylvania'},
#               {'#text': 'Pennsylvania',
#                '@href': './Pennsylvania',
#                '@id': 'mwXw',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Pennsylvania'},
#               {'#text': 'sixth-most populous city in the United States',
#                '@href': './List_of_United_States_cities_by_population',
#                '@id': 'mwZA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'List of United States cities by population'},
#               {'#text': '2020 census',
#                '@href': './2020_United_States_census',
#                '@id': 'mwZQ',
#                '@rel': 'mw:WikiLink',
#                '@title': '2020 United States census'},
#               {'#text': 'Delaware Valley',
#                '@class': 'mw-redirect',
#                '@href': './Delaware_Valley',
#                '@id': 'mwZg',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Delaware Valley'},
#               {'#text': 'ninth-largest metropolitan area',
#                '@href': './Metropolitan_statistical_area',
#                '@id': 'mwZw',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Metropolitan statistical area'},
#               {'#text': 'its culture',
#                '@href': './Culture_of_Philadelphia',
#                '@id': 'mwbA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Culture of Philadelphia'},
#               {'#text': 'cuisine',
#                '@class': 'mw-redirect',
#                '@href': './Philadelphia_cuisine',
#                '@id': 'mwbQ',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Philadelphia cuisine'},
#               {'#text': 'history',
#                '@href': './History_of_Philadelphia',
#                '@id': 'mwbg',
#                '@rel': 'mw:WikiLink',
#                '@title': 'History of Philadelphia'},
#               {'#text': 'business and industry',
#                '@href': './Economy_of_Philadelphia',
#                '@id': 'mwbw',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Economy of Philadelphia'}],
#         'b': [{'#text': 'Philadelphia', '@id': 'mwWQ'},
#               {'#text': 'Philly', '@id': 'mwXQ'}],
#         'link': {'@about': '#mwt51',
#                  '@href': './Category:Pages_including_recorded_pronunciations',
#                  '@id': 'mwWw',
#                  '@rel': 'mw:PageProp/Category'},
#         'span': {'@about': '#mwt51',
#                  '@class': 'rt-commentedText nowrap',
#                  '@data-mw': '{"parts":[{"template":{"target":{"wt":"IPAc-en","href":"./Template:IPAc-en"},"params":{"1":{"wt":"ˌ"},"2":{"wt":"f"},"3":{"wt":"ɪ"},"4":{"wt":"l"},"5":{"wt":"ə"},"6":{"wt":"ˈ"},"7":{"wt":"d"},"8":{"wt":"ɛ"},"9":{"wt":"l"},"10":{"wt":"f"},"11":{"wt":"i"},"12":{"wt":"ə"},"audio":{"wt":"LL-Q1860 '
#                              '(eng)-Flame, not '
#                              'lame-Philadelphia.wav"}},"i":0}}]}',
#                  '@id': 'mwWg',
#                  '@typeof': 'mw:Transclusion',
#                  'span': [{'@class': 'IPA nopopups noexcerpt',
#                            '@lang': 'en-fonipa',
#                            'a': {'#text': '//',
#                                  '@href': './Help:IPA/English',
#                                  '@rel': 'mw:WikiLink',
#                                  '@title': 'Help:IPA/English',
#                                  'span': {'@style': 'border-bottom:1px dotted',
#                                           'span': [{'#text': 'ˌ',
#                                                     '@title': '/ˌ/: secondary '
#                                                               'stress follows'},
#                                                    {'#text': 'f',
#                                                     '@title': "'f' in 'find'"},
#                                                    {'#text': 'ɪ',
#                                                     '@title': "/ɪ/: 'i' in "
#                                                               "'kit'"},
#                                                    {'#text': 'l',
#                                                     '@title': "'l' in 'lie'"},
#                                                    {'#text': 'ə',
#                                                     '@title': "/ə/: 'a' in "
#                                                               "'about'"},
#                                                    {'#text': 'ˈ',
#                                                     '@title': '/ˈ/: primary '
#                                                               'stress follows'},
#                                                    {'#text': 'd',
#                                                     '@title': "'d' in 'dye'"},
#                                                    {'#text': 'ɛ',
#                                                     '@title': "/ɛ/: 'e' in "
#                                                               "'dress'"},
#                                                    {'#text': 'l',
#                                                     '@title': "'l' in 'lie'"},
#                                                    {'#text': 'f',
#                                                     '@title': "'f' in 'find'"},
#                                                    {'#text': 'i',
#                                                     '@title': "/i/: 'y' in "
#                                                               "'happy'"},
#                                                    {'#text': 'ə',
#                                                     '@title': "/ə/: 'a' in "
#                                                               "'about'"}]}}},
#                           {'@typeof': 'mw:Entity'},
#                           {'@about': '#mwt52',
#                            '@class': 'ext-phonos',
#                            '@data-mw': '{"name":"phonos","attrs":{"file":"LL-Q1860 '
#                                        '(eng)-Flame, not '
#                                        'lame-Philadelphia.wav"},"body":{"extsrc":""}}',
#                            '@typeof': 'mw:Extension/phonos',
#                            'span': {'@class': 'noexcerpt '
#                                               'ext-phonos-PhonosButton '
#                                               'ext-phonos-PhonosButton-emptylabel '
#                                               'oo-ui-widget '
#                                               'oo-ui-widget-enabled '
#                                               'oo-ui-buttonElement '
#                                               'oo-ui-buttonElement-frameless '
#                                               'oo-ui-iconElement '
#                                               'oo-ui-buttonWidget',
#                                     '@data-nosnippet': '',
#                                     '@data-ooui': '{"_":"mw.Phonos.PhonosButton","href":"\\/\\/upload.wikimedia.org\\/wikipedia\\/commons\\/transcoded\\/1\\/1d\\/LL-Q1860_%28eng%29-Flame%2C_not_lame-Philadelphia.wav\\/LL-Q1860_%28eng%29-Flame%2C_not_lame-Philadelphia.wav.mp3","rel":["nofollow"],"framed":false,"icon":"volumeUp","data":{"ipa":"","text":"","lang":"en","wikibase":"","file":"LL-Q1860 '
#                                                   '(eng)-Flame, not '
#                                                   'lame-Philadelphia.wav"},"classes":["noexcerpt","ext-phonos-PhonosButton","ext-phonos-PhonosButton-emptylabel"]}',
#                                     '@id': 'ooui-php-1',
#                                     'a': {'@aria-label': 'Play audio',
#                                           '@class': 'oo-ui-buttonElement-button',
#                                           '@href': '//upload.wikimedia.org/wikipedia/commons/transcoded/1/1d/LL-Q1860_%28eng%29-Flame%2C_not_lame-Philadelphia.wav/LL-Q1860_%28eng%29-Flame%2C_not_lame-Philadelphia.wav.mp3',
#                                           '@rel': 'nofollow',
#                                           '@role': 'button',
#                                           '@tabindex': '0',
#                                           '@title': 'Play audio',
#                                           'span': [{'@class': 'oo-ui-iconElement-icon '
#                                                               'oo-ui-icon-volumeUp'},
#                                                    {'@class': 'oo-ui-labelElement-label'},
#                                                    {'@class': 'oo-ui-indicatorElement-indicator '
#                                                               'oo-ui-indicatorElement-noIndicator'}]}},
#                            'sup': {'@class': 'ext-phonos-attribution noexcerpt '
#                                              'navigation-not-searchable',
#                                    'a': {'#text': 'ⓘ',
#                                          '@href': '/wiki/File:LL-Q1860_(eng)-Flame,_not_lame-Philadelphia.wav',
#                                          '@title': 'File:LL-Q1860 (eng)-Flame, '
#                                                    'not '
#                                                    'lame-Philadelphia.wav'}}}]},
#         'sup': [{'@about': '#mwt56',
#                  '@class': 'mw-ref reference',
#                  '@data-mw': '{"name":"ref","attrs":{"name":"QuickFacts"},"body":{"id":"mw-reference-text-cite_note-QuickFacts-11"}}',
#                  '@id': 'cite_ref-QuickFacts_11-0',
#                  '@rel': 'dc:references',
#                  '@typeof': 'mw:Extension/ref',
#                  'a': {'@href': './Philadelphia#cite_note-QuickFacts-11',
#                        '@id': 'mwYA',
#                        'span': {'#text': '11',
#                                 '@class': 'mw-reflink-text',
#                                 '@id': 'mwYQ',
#                                 'span': [{'#text': '[',
#                                           '@class': 'cite-bracket',
#                                           '@id': 'mwYg'},
#                                          {'#text': ']',
#                                           '@class': 'cite-bracket',
#                                           '@id': 'mwYw'}]}}},
#                 {'@about': '#mwt59',
#                  '@class': 'mw-ref reference',
#                  '@data-mw': '{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-12"}}',
#                  '@id': 'cite_ref-12',
#                  '@rel': 'dc:references',
#                  '@typeof': 'mw:Extension/ref',
#                  'a': {'@href': './Philadelphia#cite_note-12',
#                        '@id': 'mwaA',
#                        'span': {'#text': '12',
#                                 '@class': 'mw-reflink-text',
#                                 '@id': 'mwaQ',
#                                 'span': [{'#text': '[',
#                                           '@class': 'cite-bracket',
#                                           '@id': 'mwag'},
#                                          {'#text': ']',
#                                           '@class': 'cite-bracket',
#                                           '@id': 'mwaw'}]}}},
#                 {'@about': '#mwt62',
#                  '@class': 'mw-ref reference',
#                  '@data-mw': '{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-13"}}',
#                  '@id': 'cite_ref-13',
#                  '@rel': 'dc:references',
#                  '@typeof': 'mw:Extension/ref',
#                  'a': {'@href': './Philadelphia#cite_note-13',
#                        '@id': 'mwcA',
#                        'span': {'#text': '13',
#                                 '@class': 'mw-reflink-text',
#                                 '@id': 'mwcQ',
#                                 'span': [{'#text': '[',
#                                           '@class': 'cite-bracket',
#                                           '@id': 'mwcg'},
#                                          {'#text': ']',
#                                           '@class': 'cite-bracket',
#                                           '@id': 'mwcw'}]}}},
#                 {'@about': '#mwt65',
#                  '@class': 'mw-ref reference',
#                  '@data-mw': '{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-14"}}',
#                  '@id': 'cite_ref-14',
#                  '@rel': 'dc:references',
#                  '@typeof': 'mw:Extension/ref',
#                  'a': {'@href': './Philadelphia#cite_note-14',
#                        '@id': 'mwdA',
#                        'span': {'#text': '14',
#                                 '@class': 'mw-reflink-text',
#                                 '@id': 'mwdQ',
#                                 'span': [{'#text': '[',
#                                           '@class': 'cite-bracket',
#                                           '@id': 'mwdg'},
#                                          {'#text': ']',
#                                           '@class': 'cite-bracket',
#                                           '@id': 'mwdw'}]}}}]},
#        {'#text': 'Philadelphia was founded in 1682 by , an English  and '
#                  'advocate of , and served as the capital of the colonial era '
#                  '. It then played a vital role during the  and . It served as '
#                  'the central meeting place for the  in hosting the  (1774) '
#                  'and the , during which the Founders formed the , elected  as '
#                  'its commander, and adopted the  on July 4, 1776. During the '
#                  "Revolutionary War's , the city briefly fell to the , which "
#                  'occupied Philadelphia for nine months from September 1777 to '
#                  'June 1778. Following the end of the Revolutionary War, the  '
#                  "was ratified at the . Philadelphia remained the nation's "
#                  "largest city until 1790, and it served as the nation's first "
#                  'capital from May 10, 1775, until December 12, 1776, and on  '
#                  'until 1800, when construction of the new national capital in '
#                  'Washington, D.C. was completed.',
#         '@id': 'mweA',
#         'a': [{'#text': 'William Penn',
#                '@href': './William_Penn',
#                '@id': 'mweQ',
#                '@rel': 'mw:WikiLink',
#                '@title': 'William Penn'},
#               {'#text': 'Quaker',
#                '@href': './Quakers',
#                '@id': 'mweg',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Quakers'},
#               {'#text': 'religious freedom',
#                '@href': './Freedom_of_religion',
#                '@id': 'mwew',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Freedom of religion'},
#               {'#text': 'Province of Pennsylvania',
#                '@href': './Province_of_Pennsylvania',
#                '@id': 'mwfA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Province of Pennsylvania'},
#               {'#text': 'American Revolution',
#                '@href': './American_Revolution',
#                '@id': 'mwhQ',
#                '@rel': 'mw:WikiLink',
#                '@title': 'American Revolution'},
#               {'#text': 'Revolutionary War',
#                '@href': './American_Revolutionary_War',
#                '@id': 'mwhg',
#                '@rel': 'mw:WikiLink',
#                '@title': 'American Revolutionary War'},
#               {'#text': "nation's Founding Fathers",
#                '@href': './Founding_Fathers_of_the_United_States',
#                '@id': 'mwhw',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Founding Fathers of the United States'},
#               {'#text': 'First Continental Congress',
#                '@href': './First_Continental_Congress',
#                '@id': 'mwiA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'First Continental Congress'},
#               {'#text': 'Second Continental Congress',
#                '@href': './Second_Continental_Congress',
#                '@id': 'mwiQ',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Second Continental Congress'},
#               {'#text': 'Continental Army',
#                '@href': './Continental_Army',
#                '@id': 'mwig',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Continental Army'},
#               {'#text': 'George Washington',
#                '@href': './George_Washington',
#                '@id': 'mwiw',
#                '@rel': 'mw:WikiLink',
#                '@title': 'George Washington'},
#               {'#text': 'Declaration of Independence',
#                '@href': './United_States_Declaration_of_Independence',
#                '@id': 'mwjA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'United States Declaration of Independence'},
#               {'#text': 'Philadelphia campaign',
#                '@href': './Philadelphia_campaign',
#                '@id': 'mwjQ',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Philadelphia campaign'},
#               {'#text': 'British Army',
#                '@href': './British_Army_during_the_American_Revolutionary_War',
#                '@id': 'mwjg',
#                '@rel': 'mw:WikiLink',
#                '@title': 'British Army during the American Revolutionary War'},
#               {'#text': 'U.S. Constitution',
#                '@href': './Constitution_of_the_United_States',
#                '@id': 'mwkw',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Constitution of the United States'},
#               {'#text': 'Philadelphia Convention',
#                '@href': './Constitutional_Convention_(United_States)',
#                '@id': 'mwlA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Constitutional Convention (United States)'},
#               {'#text': 'four subsequent occasions',
#                '@href': './List_of_capitals_in_the_United_States',
#                '@id': 'mwlQ',
#                '@rel': 'mw:WikiLink',
#                '@title': 'List of capitals in the United States'}],
#         'sup': [{'@about': '#mwt66',
#                  '@class': 'mw-ref reference',
#                  '@data-mw': '{"name":"ref","attrs":{"name":"weigley"}}',
#                  '@id': 'cite_ref-weigley_3-1',
#                  '@rel': 'dc:references',
#                  '@typeof': 'mw:Extension/ref',
#                  'a': {'@href': './Philadelphia#cite_note-weigley-3',
#                        '@id': 'mwfQ',
#                        'span': {'#text': '3',
#                                 '@class': 'mw-reflink-text',
#                                 '@id': 'mwfg',
#                                 'span': [{'#text': '[',
#                                           '@class': 'cite-bracket',
#                                           '@id': 'mwfw'},
#                                          {'#text': ']',
#                                           '@class': 'cite-bracket',
#                                           '@id': 'mwgA'}]}}},
#                 {'@about': '#mwt69',
#                  '@class': 'mw-ref reference',
#                  '@data-mw': '{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-15"}}',
#                  '@id': 'cite_ref-15',
#                  '@rel': 'dc:references',
#                  '@typeof': 'mw:Extension/ref',
#                  'a': {'@href': './Philadelphia#cite_note-15',
#                        '@id': 'mwgQ',
#                        'span': {'#text': '15',
#                                 '@class': 'mw-reflink-text',
#                                 '@id': 'mwgg',
#                                 'span': [{'#text': '[',
#                                           '@class': 'cite-bracket',
#                                           '@id': 'mwgw'},
#                                          {'#text': ']',
#                                           '@class': 'cite-bracket',
#                                           '@id': 'mwhA'}]}}},
#                 {'@about': '#mwt72',
#                  '@class': 'mw-ref reference',
#                  '@data-mw': '{"name":"ref","attrs":{"name":"American '
#                              'Creation"},"body":{"id":"mw-reference-text-cite_note-American_Creation-16"}}',
#                  '@id': 'cite_ref-American_Creation_16-0',
#                  '@rel': 'dc:references',
#                  '@typeof': 'mw:Extension/ref',
#                  'a': {'@href': './Philadelphia#cite_note-American_Creation-16',
#                        '@id': 'mwjw',
#                        'span': {'#text': '16',
#                                 '@class': 'mw-reflink-text',
#                                 '@id': 'mwkA',
#                                 'span': [{'#text': '[',
#                                           '@class': 'cite-bracket',
#                                           '@id': 'mwkQ'},
#                                          {'#text': ']',
#                                           '@class': 'cite-bracket',
#                                           '@id': 'mwkg'}]}}},
#                 {'@about': '#mwt75',
#                  '@class': 'mw-ref reference',
#                  '@data-mw': '{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-17"}}',
#                  '@id': 'cite_ref-17',
#                  '@rel': 'dc:references',
#                  '@typeof': 'mw:Extension/ref',
#                  'a': {'@href': './Philadelphia#cite_note-17',
#                        '@id': 'mwlg',
#                        'span': {'#text': '17',
#                                 '@class': 'mw-reflink-text',
#                                 '@id': 'mwlw',
#                                 'span': [{'#text': '[',
#                                           '@class': 'cite-bracket',
#                                           '@id': 'mwmA'},
#                                          {'#text': ']',
#                                           '@class': 'cite-bracket',
#                                           '@id': 'mwmQ'}]}}}]},
#        {'#text': "With  in the city, Philadelphia is one of the nation's "
#                  'leading centers for higher education and academic research. '
#                  'The city hosts more outdoor sculptures and murals than any '
#                  'other city in the nation. , when combined with adjacent  in '
#                  "the same , is , representing one of the nation's largest and "
#                  "the . With  and one of the nation's most loyal and "
#                  'passionate fan bases, Philadelphia is often ranked as the '
#                  "nation's best city for professional sports fans. The city "
#                  'has a culturally and  active . Philadelphia also has played '
#                  'an  in the development and evolution of American music, '
#                  'especially , , and rock.',
#         '@id': 'mwmg',
#         'a': [{'#text': '17 four-year universities and colleges',
#                '@href': './List_of_colleges_and_universities_in_Philadelphia',
#                '@id': 'mwmw',
#                '@rel': 'mw:WikiLink',
#                '@title': 'List of colleges and universities in Philadelphia'},
#               {'#text': 'Fairmount Park',
#                '@href': './Fairmount_Park',
#                '@id': 'mwrA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Fairmount Park'},
#               {'#text': 'Wissahickon Valley Park',
#                '@href': './Wissahickon_Valley_Park',
#                '@id': 'mwrQ',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Wissahickon Valley Park'},
#               {'#text': 'watershed',
#                '@href': './Drainage_basin',
#                '@id': 'mwrg',
#                '@rel': 'mw:WikiLink',
#                '@title': 'Drainage basin'},
#               {'#text': "world's 55th-largest urban park",
#                '@href': './List_of_urban_parks_by_size',
#                '@id': 'mwsA',
#                '@rel': 'mw:WikiLink',
#                '@title': 'List of urban parks by size'},
#               {'#text': 'five professional sports teams',
# ...
#                                              {'@typeof': 'mw:Entity'}]}},
#                             {'@class': 'mergedrow',
#                              'td': {'#text': '6,245,051 (US: )',
#                                     '@class': 'infobox-data',
#                                     'a': {'#text': '9th',
#                                           '@class': 'mw-redirect',
#                                           '@href': './List_of_metropolitan_statistical_areas',
#                                           '@rel': 'mw:WikiLink',
#                                           '@title': 'List of metropolitan '
#                                                     'statistical areas'}},
#                              'th': {'#text': '•',
#                                     '@class': 'infobox-label',
#                                     '@scope': 'row',
#                                     'a': {'#text': 'Metro',
#                                           '@href': './Metropolitan_area',
#                                           '@rel': 'mw:WikiLink',
#                                           '@title': 'Metropolitan area'},
#                                     'div': {'@class': 'ib-settlement-fn',
#                                             'sup': {'@about': '#mwt44',
#                                                     '@class': 'mw-ref '
#                                                               'reference',
#                                                     '@data-mw': '{"name":"ref","attrs":{"name":"2020Pop"},"body":{"id":"mw-reference-text-cite_note-2020Pop-8"}}',
#                                                     '@id': 'cite_ref-2020Pop_8-0',
#                                                     '@rel': 'dc:references',
#                                                     '@typeof': 'mw:Extension/ref',
#                                                     'a': {'@href': './Philadelphia#cite_note-2020Pop-8',
#                                                           '@id': 'mwTA',
#                                                           'span': {'#text': '8',
#                                                                    '@class': 'mw-reflink-text',
#                                                                    '@id': 'mwTQ',
#                                                                    'span': [{'#text': '[',
#                                                                              '@class': 'cite-bracket',
#                                                                              '@id': 'mwTg'},
#                                                                             {'#text': ']',
#                                                                              '@class': 'cite-bracket',
#                                                                              '@id': 'mwTw'}]}}}},
#                                     'span': [{'@typeof': 'mw:Entity'},
#                                              {'@typeof': 'mw:Entity'}]}},
#                             {'@class': 'mergedtoprow',
#                              'td': {'#text': 'Philadelphian',
#                                     '@class': 'infobox-data'},
#                              'th': {'@class': 'infobox-label',
#                                     '@scope': 'row',
#                                     'a': {'#text': 'Demonym',
#                                           '@href': './Demonym',
#                                           '@rel': 'mw:WikiLink',
#                                           '@title': 'Demonym'}}},
#                             {'@class': 'mergedtoprow',
#                              'th': {'#text': 'GDP',
#                                     '@class': 'infobox-header',
#                                     '@colspan': '2',
#                                     'div': {'@class': 'ib-settlement-fn',
#                                             'sup': {'@about': '#mwt47',
#                                                     '@class': 'mw-ref '
#                                                               'reference',
#                                                     '@data-mw': '{"name":"ref","attrs":{"name":"PhiladelphiaMetroGDP"},"body":{"id":"mw-reference-text-cite_note-PhiladelphiaMetroGDP-9"}}',
#                                                     '@id': 'cite_ref-PhiladelphiaMetroGDP_9-0',
#                                                     '@rel': 'dc:references',
#                                                     '@typeof': 'mw:Extension/ref',
#                                                     'a': {'@href': './Philadelphia#cite_note-PhiladelphiaMetroGDP-9',
#                                                           '@id': 'mwUA',
#                                                           'span': {'#text': '9',
#                                                                    '@class': 'mw-reflink-text',
#                                                                    '@id': 'mwUQ',
#                                                                    'span': [{'#text': '[',
#                                                                              '@class': 'cite-bracket',
#                                                                              '@id': 'mwUg'},
#                                                                             {'#text': ']',
#                                                                              '@class': 'cite-bracket',
#                                                                              '@id': 'mwUw'}]}}}}}},
#                             {'@class': 'mergedrow',
#                              'td': {'#text': '$518.5 billion (2022)',
#                                     '@class': 'infobox-data'},
#                              'th': {'#text': '•Philadelphia (MSA)',
#                                     '@class': 'infobox-label',
#                                     '@scope': 'row',
#                                     'span': [{'@typeof': 'mw:Entity'},
#                                              {'@typeof': 'mw:Entity'}]}},
#                             {'@class': 'mergedtoprow',
#                              'td': {'#text': '()',
#                                     '@class': 'infobox-data',
#                                     'a': [{'#text': 'UTC−5',
#                                            '@class': 'mw-redirect',
#                                            '@href': './UTC−5',
#                                            '@rel': 'mw:WikiLink',
#                                            '@title': 'UTC−5'},
#                                           {'#text': 'EST',
#                                            '@class': 'mw-redirect',
#                                            '@href': './North_American_Eastern_Time_Zone',
#                                            '@rel': 'mw:WikiLink',
#                                            '@title': 'North American Eastern '
#                                                      'Time Zone'}]},
#                              'th': {'@class': 'infobox-label',
#                                     '@scope': 'row',
#                                     'a': {'#text': 'Time zone',
#                                           '@href': './Time_zone',
#                                           '@rel': 'mw:WikiLink',
#                                           '@title': 'Time zone'}}},
#                             {'@class': 'mergedrow',
#                              'td': {'#text': '()',
#                                     '@class': 'infobox-data',
#                                     'a': [{'#text': 'UTC−4',
#                                            '@class': 'mw-redirect',
#                                            '@href': './UTC−4',
#                                            '@rel': 'mw:WikiLink',
#                                            '@title': 'UTC−4'},
#                                           {'#text': 'EDT',
#                                            '@class': 'mw-redirect',
#                                            '@href': './Eastern_Daylight_Time',
#                                            '@rel': 'mw:WikiLink',
#                                            '@title': 'Eastern Daylight Time'}]},
#                              'th': {'@class': 'infobox-label',
#                                     '@scope': 'row',
#                                     'span': {'#text': '•Summer ()',
#                                              '@class': 'nowrap',
#                                              'a': {'#text': 'DST',
#                                                    '@href': './Daylight_saving_time',
#                                                    '@rel': 'mw:WikiLink',
#                                                    '@title': 'Daylight saving '
#                                                              'time'},
#                                              'span': [{'@typeof': 'mw:Entity'},
#                                                       {'@typeof': 'mw:Entity'}]}}},
#                             {'@class': 'mergedtoprow',
#                              'td': {'@class': 'infobox-data adr',
#                                     'div': {'#text': '19092–19093, 19099, '
#                                                      '191xx',
#                                             '@class': 'postal-code'}},
#                              'th': {'@class': 'infobox-label',
#                                     '@scope': 'row',
#                                     'a': {'#text': 'ZIP Codes',
#                                           '@href': './ZIP_Code',
#                                           '@rel': 'mw:WikiLink',
#                                           '@title': 'ZIP Code'}}},
#                             {'@class': 'mergedrow',
#                              'td': {'@class': 'infobox-data',
#                                     'a': {'#text': '215, 267, 445',
#                                           '@href': './Area_codes_215,_267,_and_445',
#                                           '@rel': 'mw:WikiLink',
#                                           '@title': 'Area codes 215, 267, and '
#                                                     '445'}},
#                              'th': {'@class': 'infobox-label',
#                                     '@scope': 'row',
#                                     'a': {'#text': 'Area codes',
#                                           '@href': './Telephone_numbering_plan',
#                                           '@rel': 'mw:WikiLink',
#                                           '@title': 'Telephone numbering '
#                                                     'plan'}}},
#                             {'@class': 'mergedtoprow',
#                              'td': {'#text': '42-60000',
#                                     '@class': 'infobox-data'},
#                              'th': {'@class': 'infobox-label',
#                                     '@scope': 'row',
#                                     'a': {'#text': 'FIPS code',
#                                           '@href': './Federal_Information_Processing_Standards',
#                                           '@rel': 'mw:WikiLink',
#                                           '@title': 'Federal Information '
#                                                     'Processing Standards'}}},
#                             {'@class': 'mergedrow',
#                              'td': {'#text': '1215531',
#                                     '@class': 'infobox-data',
#                                     'sup': {'@about': '#mwt50',
#                                             '@class': 'mw-ref reference',
#                                             '@data-mw': '{"name":"ref","attrs":{},"body":{"id":"mw-reference-text-cite_note-10"}}',
#                                             '@id': 'cite_ref-10',
#                                             '@rel': 'dc:references',
#                                             '@typeof': 'mw:Extension/ref',
#                                             'a': {'@href': './Philadelphia#cite_note-10',
#                                                   '@id': 'mwVA',
#                                                   'span': {'#text': '10',
#                                                            '@class': 'mw-reflink-text',
#                                                            '@id': 'mwVQ',
#                                                            'span': [{'#text': '[',
#                                                                      '@class': 'cite-bracket',
#                                                                      '@id': 'mwVg'},
#                                                                     {'#text': ']',
#                                                                      '@class': 'cite-bracket',
#                                                                      '@id': 'mwVw'}]}}}},
#                              'th': {'#text': 'feature ID',
#                                     '@class': 'infobox-label',
#                                     '@scope': 'row',
#                                     'a': {'#text': 'GNIS',
#                                           '@href': './Geographic_Names_Information_System',
#                                           '@rel': 'mw:WikiLink',
#                                           '@title': 'Geographic Names '
#                                                     'Information System'}}},
#                             {'@class': 'mergedtoprow',
#                              'td': {'@class': 'infobox-data',
#                                     'span': [{'@class': 'url',
#                                               'a': {'#text': 'phila.gov',
#                                                     '@class': 'external text',
#                                                     '@href': 'https://phila.gov',
#                                                     '@rel': 'mw:ExtLink '
#                                                             'nofollow',
#                                                     'wbr': None}},
#                                              {'@class': 'noprint',
#                                               '@data-mw': '{"attribs":[["text_top",{"txt":"text_top"}]],"caption":"Edit '
#                                                           'this at Wikidata"}',
#                                               '@typeof': 'mw:File/Frameless',
#                                               'a': {'@href': 'https://www.wikidata.org/wiki/Q1345#P856',
#                                                     '@title': 'Edit this at '
#                                                               'Wikidata',
#                                                     'img': {'@alt': 'Edit this '
#                                                                     'at '
#                                                                     'Wikidata',
#                                                             '@class': 'mw-file-element',
#                                                             '@data-file-height': '20',
#                                                             '@data-file-type': 'drawing',
#                                                             '@data-file-width': '20',
#                                                             '@decoding': 'async',
#                                                             '@height': '10',
#                                                             '@resource': './File:OOjs_UI_icon_edit-ltr-progressive.svg',
#                                                             '@src': '//upload.wikimedia.org/wikipedia/en/thumb/8/8a/OOjs_UI_icon_edit-ltr-progressive.svg/20px-OOjs_UI_icon_edit-ltr-progressive.svg.png',
#                                                             '@width': '10'}}}]},
#                              'th': {'#text': 'Website',
#                                     '@class': 'infobox-label',
#                                     '@scope': 'row'}}]}}}

# %% [markdown]
# ## 3.2 API authentication
# The GitHub and SEPTA examples we've looked at so far are APIs that don't require any authentication to access. Anyone can send a request to these APIs and receive a response. There are, however, quite a few APIs that require the user to have some authentication. This authentication usually takes the form of an access token that needs to be obtained from the API provider before making requests.
#
# ### 3.2.1 Example: Sportradar
# As an example, we'll take a look at one of the [Sportradar APIs](https://developer.sportradar.com). Sportradar has APIs for a number of different sports.
#
# In order to use any of their APIs, Sportradar requires you to open a developer account and register an app. Only then you are granted an access token or "API key", which you must plug in to any requests you make.
#
# The steps to obtain an API key from Sportradar are:
# 1. Sign up as a developer [here](https://developer.sportradar.com/member/register)
# 2. Sign in to your account and go your [account page](https://developer.sportradar.com/member/my-account)
# 3. Go to your [applications page](https://developer.sportradar.com/apps/myapps)
# 4. Register a new application and select the API keys you need
#
# We'll use the Sportradar Soccer API to obtain the match schedules for the English premier league.
#
# First, we'll construct the request address using the API key.

# %%
# plug your key here
soccer_key = ""

# %%
# format: https://api.sportradar.us/soccer-extended/{access_level}/{version}/{language_code}/competitors/{competitor_id}/summaries.{format}?api_key={your_api_key}
address = "https://api.sportradar.us/soccer-extended/trial/v4/en/competitors/sr:competitor:17/summaries.json?api_key=" + soccer_key

# %%
resp = requests.get(address)

# %%
result = resp.json()

# %%
print(result)
# Out:
# {'generated_at': '2025-10-07T16:11:14+00:00', 'summaries': [{'sport_event': {'id': 'sr:sport_event:61300633', 'start_time': '2025-10-05T15:30:00+00:00', 'start_time_confirmed': True, 'sport_event_context': {'sport': {'id': 'sr:sport:1', 'name': 'Soccer'}, 'category': {'id': 'sr:category:1', 'name': 'England', 'country_code': 'ENG'}, 'competition': {'id': 'sr:competition:17', 'name': 'Premier League', 'gender': 'men'}, 'season': {'id': 'sr:season:130281', 'name': 'Premier League 25/26', 'start_date': '2025-08-15', 'end_date': '2026-05-24', 'year': '25/26', 'competition_id': 'sr:competition:17'}, 'stage': {'order': 1, 'type': 'league', 'phase': 'regular season', 'start_date': '2025-08-15', 'end_date': '2026-05-24', 'year': '25/26'}, 'round': {'number': 7}, 'groups': [{'id': 'sr:league:95139', 'name': 'Premier League 25/26'}]}, 'coverage': {'type': 'sport_event', 'sport_event_properties': {'lineups': True, 'formations': True, 'venue': True, 'extended_play_by_play': True, 'extended_player_stats': True, 'extended_team_stats': True, 'lineups_availability': 'pre', 'ballspotting': True, 'commentary': True, 'fun_facts': True, 'goal_scorers': True, 'goal_scorers_live': True, 'scores': 'live', 'game_clock': True, 'deeper_play_by_play': True, 'deeper_player_stats': True, 'deeper_team_stats': True, 'basic_play_by_play': True, 'basic_player_stats': True, 'basic_team_stats': True}}, 'competitors': [{'id': 'sr:competitor:50', 'name': 'Brentford FC', 'country': 'England', 'country_code': 'ENG', 'abbreviation': 'BRE', 'qualifier': 'home', 'gender': 'male'}, {'id': 'sr:competitor:17', 'name': 'Manchester City', 'country': 'England', 'country_code': 'ENG', 'abbreviation': 'MCI', 'qualifier': 'away', 'gender': 'male'}], 'venue': {'id': 'sr:venue:53349', 'name': 'Brentford Community Stadium', 'capacity': 17250, 'city_name': 'London', 'country_name': 'England', 'map_coordinates': '51.4907295, -0.2891696', 'country_code': 'ENG', 'timezone': 'Europe/London'}, 'channels': [{'name': 'Telemundo', 'country': 'United States', 'country_code': 'USA'}, {'name': 'USA Network', 'url': 'https://www.usanetwork.com/', 'country': 'United States', 'country_code': 'USA'}, {'name': 'Fubo TV', 'url': 'https://www.livesoccertv.com/channels/fubo-tv/', 'country': 'United States', 'country_code': 'USA'}], 'sport_event_conditions': {'referees': [{'id': 'sr:referee:74774', 'name': 'England, Darren', 'nationality': 'England', 'country_code': 'ENG', 'type': 'main_referee'}, {'id': 'sr:referee:79890', 'name': 'Ledger, Scott', 'nationality': 'England', 'country_code': 'ENG', 'type': 'first_assistant_referee'}, {'id': 'sr:referee:81631', 'name': 'Greenhalgh, Nicholas', 'nationality': 'England', 'country_code': 'ENG', 'type': 'second_assistant_referee'}, {'id': 'sr:referee:79884', 'name': 'Madley, Andrew', 'nationality': 'England', 'country_code': 'ENG', 'type': 'fourth_official'}, {'id': 'sr:referee:2067785', 'name': 'Howard, Paul', 'nationality': 'England', 'country_code': 'ENG', 'type': 'video_assistant_referee'}], 'weather': {'pitch_conditions': 'good', 'overall_conditions': 'good'}, 'ground': {'neutral': False}, 'lineups': {'confirmed': True}}}, 'sport_event_status': {'status': 'closed', 'match_status': 'ended', 'home_score': 0, 'away_score': 1, 'winner_id': 'sr:competitor:17', 'period_scores': [{'home_score': 0, 'away_score': 1, 'type': 'regular_period', 'number': 1}, {'home_score': 0, 'away_score': 0, 'type': 'regular_period', 'number': 2}], 'ball_locations': [{'order': 4, 'x': 0, 'y': 0, 'qualifier': 'away'}, {'order': 3, 'x': 44, 'y': 100, 'qualifier': 'away'}, {'order': 2, 'x': 58, 'y': 82, 'qualifier': 'away'}, {'order': 1, 'x': 95, 'y': 54, 'qualifier': 'away'}], 'match_situation': {'status': 'safe', 'qualifier': 'away', 'updated_at': '2025-10-05T17:24:26+00:00'}}, 'statistics': {'totals': {'competitors': [{'id': 'sr:competitor:50', 'name': 'Brentford FC', 'abbreviation': 'BRE', 'qualifier': 'home', 'statistics': {'ball_possession': 30, 'cards_given': 3, 'chances_creat ...

# %%
summaries = result["summaries"]
print(type(summaries))
print(len(summaries))
# Out:
# <class 'list'>
# 68

# %%
print(summaries[0])
# Out:
# {'sport_event': {'id': 'sr:sport_event:61300633', 'start_time': '2025-10-05T15:30:00+00:00', 'start_time_confirmed': True, 'sport_event_context': {'sport': {'id': 'sr:sport:1', 'name': 'Soccer'}, 'category': {'id': 'sr:category:1', 'name': 'England', 'country_code': 'ENG'}, 'competition': {'id': 'sr:competition:17', 'name': 'Premier League', 'gender': 'men'}, 'season': {'id': 'sr:season:130281', 'name': 'Premier League 25/26', 'start_date': '2025-08-15', 'end_date': '2026-05-24', 'year': '25/26', 'competition_id': 'sr:competition:17'}, 'stage': {'order': 1, 'type': 'league', 'phase': 'regular season', 'start_date': '2025-08-15', 'end_date': '2026-05-24', 'year': '25/26'}, 'round': {'number': 7}, 'groups': [{'id': 'sr:league:95139', 'name': 'Premier League 25/26'}]}, 'coverage': {'type': 'sport_event', 'sport_event_properties': {'lineups': True, 'formations': True, 'venue': True, 'extended_play_by_play': True, 'extended_player_stats': True, 'extended_team_stats': True, 'lineups_availability': 'pre', 'ballspotting': True, 'commentary': True, 'fun_facts': True, 'goal_scorers': True, 'goal_scorers_live': True, 'scores': 'live', 'game_clock': True, 'deeper_play_by_play': True, 'deeper_player_stats': True, 'deeper_team_stats': True, 'basic_play_by_play': True, 'basic_player_stats': True, 'basic_team_stats': True}}, 'competitors': [{'id': 'sr:competitor:50', 'name': 'Brentford FC', 'country': 'England', 'country_code': 'ENG', 'abbreviation': 'BRE', 'qualifier': 'home', 'gender': 'male'}, {'id': 'sr:competitor:17', 'name': 'Manchester City', 'country': 'England', 'country_code': 'ENG', 'abbreviation': 'MCI', 'qualifier': 'away', 'gender': 'male'}], 'venue': {'id': 'sr:venue:53349', 'name': 'Brentford Community Stadium', 'capacity': 17250, 'city_name': 'London', 'country_name': 'England', 'map_coordinates': '51.4907295, -0.2891696', 'country_code': 'ENG', 'timezone': 'Europe/London'}, 'channels': [{'name': 'Telemundo', 'country': 'United States', 'country_code': 'USA'}, {'name': 'USA Network', 'url': 'https://www.usanetwork.com/', 'country': 'United States', 'country_code': 'USA'}, {'name': 'Fubo TV', 'url': 'https://www.livesoccertv.com/channels/fubo-tv/', 'country': 'United States', 'country_code': 'USA'}], 'sport_event_conditions': {'referees': [{'id': 'sr:referee:74774', 'name': 'England, Darren', 'nationality': 'England', 'country_code': 'ENG', 'type': 'main_referee'}, {'id': 'sr:referee:79890', 'name': 'Ledger, Scott', 'nationality': 'England', 'country_code': 'ENG', 'type': 'first_assistant_referee'}, {'id': 'sr:referee:81631', 'name': 'Greenhalgh, Nicholas', 'nationality': 'England', 'country_code': 'ENG', 'type': 'second_assistant_referee'}, {'id': 'sr:referee:79884', 'name': 'Madley, Andrew', 'nationality': 'England', 'country_code': 'ENG', 'type': 'fourth_official'}, {'id': 'sr:referee:2067785', 'name': 'Howard, Paul', 'nationality': 'England', 'country_code': 'ENG', 'type': 'video_assistant_referee'}], 'weather': {'pitch_conditions': 'good', 'overall_conditions': 'good'}, 'ground': {'neutral': False}, 'lineups': {'confirmed': True}}}, 'sport_event_status': {'status': 'closed', 'match_status': 'ended', 'home_score': 0, 'away_score': 1, 'winner_id': 'sr:competitor:17', 'period_scores': [{'home_score': 0, 'away_score': 1, 'type': 'regular_period', 'number': 1}, {'home_score': 0, 'away_score': 0, 'type': 'regular_period', 'number': 2}], 'ball_locations': [{'order': 4, 'x': 0, 'y': 0, 'qualifier': 'away'}, {'order': 3, 'x': 44, 'y': 100, 'qualifier': 'away'}, {'order': 2, 'x': 58, 'y': 82, 'qualifier': 'away'}, {'order': 1, 'x': 95, 'y': 54, 'qualifier': 'away'}], 'match_situation': {'status': 'safe', 'qualifier': 'away', 'updated_at': '2025-10-05T17:24:26+00:00'}}, 'statistics': {'totals': {'competitors': [{'id': 'sr:competitor:50', 'name': 'Brentford FC', 'abbreviation': 'BRE', 'qualifier': 'home', 'statistics': {'ball_possession': 30, 'cards_given': 3, 'chances_created': 3, 'clearances': 27, 'corner_kicks': 3, 'crosses_succes ...

# %%
summaries[0].keys()
# Out:
# dict_keys(['sport_event', 'sport_event_status', 'statistics'])

# %%
(summaries[0]['sport_event']['competitors'])
# Out:
# [{'id': 'sr:competitor:50',
#   'name': 'Brentford FC',
#   'country': 'England',
#   'country_code': 'ENG',
#   'abbreviation': 'BRE',
#   'qualifier': 'home',
#   'gender': 'male'},
#  {'id': 'sr:competitor:17',
#   'name': 'Manchester City',
#   'country': 'England',
#   'country_code': 'ENG',
#   'abbreviation': 'MCI',
#   'qualifier': 'away',
#   'gender': 'male'}]

# %% [markdown]
# ### 3.3 Big Tech APIs
#
# Large tech companies make a variety of APIs available for use. Most of these require authentication and can be used to access some very useful data.
#
# #### 3.3.1 Facebook
#
# Facebook has an API called the Graph API that allows a developer to access data about posts, comments, users and more. However, one of the major sticking points of working with APIs from companies like Facebook is that these APIs change very frequently, and sometimes the changes can break a developer's code. Facebook changed their policy towards applications some time ago, and as a result, a developer simply working on a research project is not allowed access to any data from the Graph API. In order to gain data access, all developers must register their application and go through a review process with Facebook. Only then is data collection allowed through the API. These barriers make it hard to discuss and work with the Graph API.
#
# #### 3.3.2 Google
#
# Similarly, Google Maps has a very powerful API that can be used to obtain a large variety of data, however, it is meant to be used as a licensed resource for which developers pay Google a fee. Some of Google's tools may be used for free by obtaining a \$200 API credit, however, this still requires setting up billing. If you are interested in these tools, take a look [here](https://cloud.google.com/maps-platform/pricing/).
#
# An important consideration when working with these APIs is that companies usually enforce a "rate limit". This means a developer is only allowed to make calls under a certain frequency. When you are working with an API from a commercial entity, make sure to check on their rate limit.
#
# #### 3.3.3 Twitter
#
# A big-tech API we can demonstrate and play around with is the Twitter API. While the API can be accessed in a barebones way usings tools such as the `requests` module, we can also use an API client, which is a third-party library that allows us to easily work with an API by automating and simplifying low-level tasks.
#
# For Twitter, we'll use a client called tweepy (`pip3 install tweepy` to install). First, we'll need to follow these steps to obtain API access and authentication:
#
# 1. Sign up for a Twitter account
# 2. Sign in to [https://developer.twitter.com]
# 3. Create an app
# 4. Go to the API Keys section and click "Generate ACCESS TOKEN".
#
# The resulting keys are:
# - "oauth_access_token"
# - "oauth_access_token_secret"
# - "consumer_key"
# - "consumer_secret"
#
# We'll have to save these values in some variables that we'll need:
#
# **[Please be noted for Twitter API, you may have to pay to have the valid response]**

# %%
# plug your keys here (only the bearer_token is needed for the examples below)

consumer_key = ""
consumer_secret = ""
access_token = ""
access_token_secret = ""
bearer_token = ""

# %% [markdown]
# Now, we'll create a `twitter` object using our consumer key and secret and use this object to download the top tweets by the Eagles organization (NFL team).

# %%
# !pip3 install tweepy --upgrade
import tweepy
# Out:
# Requirement already satisfied: tweepy in /usr/local/lib/python3.12/dist-packages (4.16.0)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from tweepy) (3.3.1)
# Requirement already satisfied: requests<3,>=2.27.0 in /usr/local/lib/python3.12/dist-packages (from tweepy) (2.32.4)
# Requirement already satisfied: requests-oauthlib<3,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from tweepy) (2.0.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27.0->tweepy) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27.0->tweepy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27.0->tweepy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27.0->tweepy) (2025.8.3)

# %%
#twitter = twython.Twython(consumer_key, consumer_secret, access_token, access_token_secret)
#twitter.get #show_user(screen_name='realdonaldtrump')

client = tweepy.Client(bearer_token)

# %%
query = 'from:Eagles'

tweets = client.search_recent_tweets(query=query, tweet_fields=['created_at'], max_results=10)

for tweet in tweets.data:
    print(tweet.data['created_at'])
    print(tweet.text)
    print("")
# Out:
# 2025-10-07T15:34:33.000Z
# 📺: #PHIvsNYG | Thursday, October 9 at 8:15 PM on @NFLonPrime
#
# 2025-10-07T15:34:32.000Z
# Had to start off Giants week with this one https://t.co/ARoFsWn227
#
# 2025-10-06T20:57:56.000Z
# Monday's Injury Report
#
# #PHIvsNYG https://t.co/iafJIrLOLf
#
# 2025-10-06T19:21:45.000Z
# Head Coach Nick Sirianni speaks with the media. #FlyEaglesFly https://t.co/0U174AtiES
#
# 2025-10-06T18:32:51.000Z
# .@devontasmith's 114 yards yesterday marked his 14th career game with 100+ receiving yards (including playoffs) ✔️ https://t.co/xWpATtzfMP
#
# 2025-10-06T18:24:59.000Z
# .@devontasmith's 114 yards yesterday marked his 11th career game with 100+ receiving yards (including playoffs) ✔️ https://t.co/KYNkwsT0Nz
#
# 2025-10-06T18:22:59.000Z
# .@devontasmith 's 114 yards yesterday marked his 11th career game with 100+ receiving yards (including playoffs) ✔️ https://t.co/KLIbsU5vKs
#
# 2025-10-06T16:11:38.000Z
# Fix the mistakes, get ready for Thursday https://t.co/R6RqBhFTVD
#
# 2025-10-05T21:47:14.000Z
# "We will learn from it." - @JalenHurts https://t.co/tFyCX1UBHA
#
# 2025-10-05T21:13:51.000Z
# Head Coach Nick Sirianni and Eagles players speak with the media. #FlyEaglesFly https://t.co/qQQ1WZSEPo

# %% [markdown]
# 3.3.4 Yelp
# Yelp Fusion API is a REST API that gived access to information across countries. The Yelp Fusion API uses private key authentication to authenticate all endpoints. First, we'll need to follow these steps to obtain API access and authentication:
#
# Sign up for a Yelp account
# Sign in to [https://www.yelp.com/developers]
# Manage API Access, Create an app
# Go to the Manage App section and view API Key
# We'll have to save API Key for requests. For more details, please check Yelp Fusion API Documentation

# %%
API_Key = 'h2vah-jJc8vgmIsWxlEy6KGGaZmrJDLu0mf9BMJhmLQxnnCXX2KyJVMfgpXG0AI5Nz3R6lAYQhBLyoItU-HXFbWYrp5TVpbNhxF-BBZxPgHQesDTTNbRzFnW00HlaHYx'

# %%
url = 'https://api.yelp.com/v3/businesses/search'
parameters = {
    'location': "3675 Market Street, Philadelphia, PA 19104",
    'raduis':200,
    'categories': 'french',
    'price': "1,2,3",
    'sort_by': "rating",
    'limit': 6

}
headers = {
    "Authorization": 'Bearer %s' % API_Key
}

response = requests.get(url, headers=headers, params=parameters)
response
# Out:
# <Response [200]>

# %%
businesses = response.json()

for business in businesses['businesses']:
    print('Name:', business['name'])
    print('Location:',business['location']['display_address'])
    print('Distance:',business['distance'])
    print('Rating:',business['rating'])
    print('ReviewCount:',business['review_count'])
    print('Price:',business['price'])
    print('Phone:',business['phone'])
    print()
# Out:
# Name: Jessica's Restaurant
# Location: ['250 South Ave', 'Ste 104', 'Fanwood, NJ 07023']
# Distance: 102538.34372270961
# Rating: 4.7
# ReviewCount: 387
# Price: $$$
# Phone: +19087542080
#
# Name: Josephine's
# Location: ['50 W Grant St', 'Lancaster, PA 17603']
# Distance: 95154.95332429916
# Rating: 4.6
# ReviewCount: 55
# Price: $$$
# Phone: +17172997090
#
# Name: La Kang Thai French Cuisine
# Location: ['190 S Greenwood Ave', 'Easton, PA 18045']
# Distance: 80834.73485251189
# Rating: 4.6
# ReviewCount: 131
# Price: $$
# Phone: +16104380301
#
# Name: 4 Seasons Mediterranean Restaurant
# Location: ['322 S Main St', 'Wharton, NJ 07885']
# Distance: 115967.39674714496
# Rating: 4.6
# ReviewCount: 267
# Price: $$
# Phone: +18622449777
#
# Name: Bistro d’Azur
# Location: ['14 Academy St', 'South Orange, NJ 07079']
# Distance: 118299.48217414257
# Rating: 4.6
# ReviewCount: 140
# Price: $$$
# Phone: +19733279725
#
# Name: Wasai Bistro
# Location: ['232 Centennial Ave', 'Cranford, NJ 07016']
# Distance: 108441.38387155002
# Rating: 4.5
# ReviewCount: 179
# Price: $$$
# Phone: +19082766600
